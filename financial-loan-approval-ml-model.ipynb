# %% [markdown]
# ### Table of Content

# %% [markdown]
# - Introduction
#   - Defination On Bussiness Task
#     - Primary Task Topic
#     - Problem solving
#     - Benefit for Company
# - Data Collection
#   - Data Dictionary
# - Import necessary packages (modules)
# - Create messy dataset
# - Data preprocessing
#   - Data cleaning
#     - Set up DataFrame, check DataFrame, and Basic EDA
#     - Dealing with missing values and abnormal value in DataFrame
#       - Find and dealing with abnormal value in DataFrame
#       - Dealing with Missing Value
#       - Detect Outlier and dealing with Outlier
# - Data Exploration
#   - Distribution of each Feature
#   - Feature analysis
# - Feature Engineer
#   - Encoding categorical attributes
#   - Scaling features
#   - Split the data
#   - Dimensionality Reduction
#   - Oversampling
# - Train models
#   - Machine Learning Model
#     - Logistic Regression
#     - Naive Bayes
#     - Support Vector Machine
#     - K-Nearest Neighbor
#     - Decision Tree
#   - Ensemble Learning Model
#     - Random Forest Classifier
#     - Gradient Boosting Classifier
#     - eXtreme Gradient Boosting (XGBoost)
#     - LightGBM
#   - Hyperparameter Tuning
#     - Algorithm selection
#     - Hyperparameter tuning (Grid Search) and Model Validation
# - Model Evaluation
#   - Re-train the model
#   - Computing evaluation matrix
#     - Confusion Matrix and Classification Report
#     - Accuracy, Precision, Recall, and F1-Score
#     - ROC Curve and Area under ROC Curve (AUC)
# - Discussion and Conclusion
#   - Conclusion
#   - Discussion

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Defination On Bussiness Task

# %% [markdown]
# **Primary Task Topic**

# %% [markdown]
# This project aims to address a critical business challenge faced by a growing global banking company: the inefficiency of its manual loan application review process. The high volume of loan requests has overwhelmed the loan team, leading to delays that result in lost revenue for the bank. As a data scientist, I will develop and deploy a highly accurate machine learning model to automate the loan approval process, classifying applicants as either approved or rejected. The primary objective is to create a solution that not only streamlines operations but also maximizes profitability by accurately identifying low-risk borrowers.

# %% [markdown]
# **Business Problem**

# %% [markdown]
# A significant surge in loan applications has strained the current manual review process at our banking institution. This labor-intensive process, which relies on a team of human analysts, is proving to be a bottleneck that prevents the bank from making timely decisions. As a result, the company is unable to capitalize on potential interest revenue from qualified applicants and is exposed to increased risk from potential defaults. The core business problem is the need for a scalable, efficient, and reliable system to handle the increasing demand for loan services while mitigating financial risk.

# %% [markdown]
# **Proposed Solution**

# %% [markdown]
# To solve this problem, I will construct a supervised machine learning model using historical data gathered from the finance team. This model will be trained to learn the intricate patterns and criteria that have historically led to successful loan repayments. By leveraging this past data, the model will be able to accurately predict the likelihood of an applicant defaulting. The outcome will be a robust predictive tool that can determine whether a loan application should be approved or rejected, thereby providing the loan team with a powerful, data-driven decision-making for financial aid.

# %% [markdown]
# **Anticipated Business Impact**

# %% [markdown]
# The implementation of this machine learning model is expected to deliver significant benefits to the company. First, by automating the loan classification process, the bank can dramatically reduce operational costs associated with manual labor and reallocate valuable employee resources to other strategic tasks. Second, the model will enable faster loan approvals, allowing the bank to capture interest revenue in a more timely manner and gain a competitive advantage in the market. Most importantly, the model's ability to accurately reject high-risk applicants will directly mitigate financial losses from loan defaults, contributing to the bank's long-term financial stability and profitability.

# %% [markdown]
# ## Methodology and Data

# %% [markdown]
# **Data Collection and Features**

# %% [markdown]
# The dataset for this project has been collected from the bank’s internal database, containing historical loan applications and their corresponding outcomes. The data includes a set of key features that are crucial for evaluating an applicant's financial stability and creditworthiness. These features are:
#
# - Education
# - Family Size
# - Employment Status (self-employed or corporate employee)
# - Annual Income
# - Loan Request Amount
# - Loan Term
# - Government Credit Score
# - Real Estate Assets
# - Commercial Assets
# - Luxury Assets
# - Bank Assets

# %% [markdown]
# **Problem Formulation**

# %% [markdown]
# Based on the nature of the data and the project's goal, this task can be formulated as a supervised classification problem. The input features listed above will be used to train the model, while the loan status (approved or rejected) will serve as the categorical target label. The binary nature of the target variable makes classification algorithms the most suitable choice. Potential models to be evaluated for this task include Logistic Regression, Decision Trees, and Random Forest Classifiers, among others.

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# The data that my company has is the previous data with previous campaigns until present (assume), which customer companies hired my company to do an online advertisement for them. This data is stored in data based on my companies, and it contains all of these columns :

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-za14{border-color:inherit;text-align:left;vertical-align:bottom}
# .tg .tg-7zrl{text-align:left;vertical-align:bottom}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-za14">Column Name</th>
#     <th class="tg-7zrl">Data Type</th>
#     <th class="tg-7zrl">Description</th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-7zrl">Campaign_ID</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">Unique identifier for each advertising campaign.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Target_Audience</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The demographic group targeted by the campaign (e.g., 'Women 18-24', 'Men 45-60', 'All Ages').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Campaign_Goal</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The primary objective of the campaign (e.g., 'Brand Awareness', 'Product Launch', 'Increase Sales').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Duration</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The length of time the campaign ran for (e.g., '15 Days').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Channel_Used</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The social media platform where the ad was placed (e.g., 'Facebook', 'Instagram', 'Pinterest', 'Twitter').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Conversion_Rate</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">The percentage of users who completed a desired action (e.g., purchase, sign-up) after clicking the ad.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Acquisition_Cost</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">The cost associated with acquiring a conversion or customer through the campaign.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">ROI</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">The return on investment, calculated as the revenue generated minus the ad spend, divided by the ad spend.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Location</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The geographical area targeted by the campaign (e.g., 'Los Angeles', 'Miami', 'Austin', 'Las Vegas').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Language</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The language of the ad campaign (e.g., 'English', 'Spanish', 'French').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Clicks</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">The total number of times the ad was clicked.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Impressions</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">The total number of times the ad was displayed to users.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Engagement_Score</td>
#     <td class="tg-7zrl">Numeric</td>
#     <td class="tg-0lax">A metric representing user interaction with the ad (e.g., likes, comments, shares).</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Customer_Segmentation</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The category of customers targeted by the ad (e.g., 'Health', 'Food', 'Home', 'Fashion', 'Technology').</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Date</td>
#     <td class="tg-7zrl">Date</td>
#     <td class="tg-0lax">The date on which the ad campaign was active.</td>
#   </tr>
#   <tr>
#     <td class="tg-7zrl">Company</td>
#     <td class="tg-7zrl">Text</td>
#     <td class="tg-0lax">The name of the company or brand running the ad campaign.</td>
#   </tr>
# </tbody></table>

# %% [markdown]
# **Description of Columns**
#
# - loan_id
#     - ID of applicant applying for loan
# - no_of_dependents
#     - Number of people in the family of the loan applicant
# - education
#     - education of the applicant (graduate bachelor degree or not graduate bachelor degree)
# - self_employed
#     - employment status of the applicant
# - income_annum
#     - annual income of the applicant (income per year). In this dataset, the unit is the US dollar.
# - loan_amount
#     - loan request amount from the applicant. In this dataset, the unit is the US dollar.
# - loan_term
#     - loan term request or committed by the applicant (in years). In this dataset, the unit is the US dollar.
# - cibil_score
#     - government credit score
# - residential_assets_value
#     - total value of real estate assets of the applicant. In this dataset, the unit is the US dollar.
# - commercial_assets_value
#     - total value of commercial assets of the applicant. In this dataset, the unit is the US dollar.
# - luxury_assets_value
#     - total value of luxury assets of the applicant. In this dataset, the unit is the US dollar.
# - bank_asset_value
#     - total value of bank assets of the applicant. In this dataset, the unit is the US dollar.
# - loan_status
#     - loan approval status that the finance team (loan approve team) approved or rejected in the past (target label)

# %% [markdown]
# **Dataset source from Kaggle** : [Dataset source click here](https://www.kaggle.com/datasets/architsharma01/loan-approval-prediction-dataset)

# %% [markdown]
# **Link :** https://www.kaggle.com/datasets/architsharma01/loan-approval-prediction-dataset

# %% [markdown]
# # Import necessary libraries

# %%
! pip install --upgrade scikit-learn xgboost
# Out:
# ...
#   Using cached scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# ...
# Using cached scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# ...

# %%
# !pip install pandas

# %%
# !pip install scikit-learn

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.7.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: bayesian-optimization, Boruta, category_encoders, cesium, eli5, fastai, hdbscan, hep_ml, imbalanced-learn, librosa, lime, mlxtend, nilearn, pyLDAvis, pynndescent, rgf-python, scikit-learn-intelex, scikit-optimize, scikit-plot, sentence-transformers, shap, sklearn-compat, sklearn-pandas, TPOT, tsfresh, umap-learn, woodwork, yellowbrick

# %%
# !pip install matplotlib

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.7.2
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: arviz, bigframes, Cartopy, catboost, datascience, fastai, geemap, ipympl, lime, matplotlib-venn, missingno, mlxtend, mne, mpld3, music21, phik, plotnine, prophet, PyUpSet, scikit-plot, seaborn, stable-baselines3, vtk, wordcloud, ydata-profiling, yellowbrick

# %%
# !pip install seaborn

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno, ydata-profiling

# %%
# !pip install imblearn
# Out:
# ...
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.1
#     Uninstalling scikit-learn-1.7.1:
#       Successfully uninstalled scikit-learn-1.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import RobustScaler
import sklearn.model_selection
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import sklearn.svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Create messy dataset

# %% [markdown]
# ### Creating a "Messy" Dataset for Demonstration

# %% [markdown]
# To simulate a real-world data cleaning scenario, a "dirty" version of the dataset is created. This process involves intentionally introducing missing values (NaN) and non-numeric characters (&, ?, @) into the DataFrame. This step serves as a demonstration of robust data preprocessing skills.
#
# **Null Value Injection**
#
# Random NaN values are inserted into a selected number of columns. This mimics common data collection issues where information may not be recorded for all entries.
#
# **Abnormal Value Injection**
#
# To further simulate a messy dataset, non-standard characters are randomly inserted into the categorical columns. This introduces a realistic data quality problem that requires a systematic approach to cleaning and handling.
#
# **Verification of Unclean Data**
#
# After the intentional introduction of errors, the dataset is inspected again to confirm the presence of the newly created missing values and abnormal characters. The number of null values for each column is tallied to provide a clear picture of the data's current state, setting the stage for the next phase of the project: data cleaning.

# %% [markdown]
# **Load Dataset**

# %% [markdown]
# - Loading dataset and displaying all the columns in dataset to see detail of each column in dataset.
# - Show all columns of Dataframe to compare and check information with the data dictionary.

# %%
loanapproval_df = pd.read_csv("/kaggle/input/loan-approval-prediction-dataset/loan_approval_dataset.csv")
pd.set_option('display.max_columns', None)
loanapproval_df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %% [markdown]
# **Check Basic Information**

# %% [markdown]
# - Check basic information about dataset before insert NaN and abnormal values.

# %% [markdown]
# **Shape of dataset**

# %% [markdown]
# - Check number of rows and columns.

# %%
print(loanapproval_df.shape)
# Out:
# (4269, 13)

# %%
print("Number of rows : ",loanapproval_df.shape[0])
print("Number of columns : ",loanapproval_df.shape[1])
# Out:
# Number of rows :  4269
# Number of columns :  13

# %%
loanapproval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %% [markdown]
# **Re-Format of columns name**

# %% [markdown]
# - In this dataset, it contained space before name of each column, so I have to remove those space to easy to handle with this dataset.

# %%
loanapproval_df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
loanapproval_df = loanapproval_df.rename(columns={'loan_id':'loan_id', ' no_of_dependents':'no_of_dependents', ' education':'education', ' self_employed':'self_employed',
       ' income_annum':'income_annum', ' loan_amount':'loan_amount', ' loan_term':'loan_term', ' cibil_score':'cibil_score',
       ' residential_assets_value':'residential_assets_value', ' commercial_assets_value':'commercial_assets_value',
       ' luxury_assets_value':'luxury_assets_value', ' bank_asset_value':'bank_asset_value', ' loan_status':'loan_status'})

# %% [markdown]
# **Check Basic Information**

# %%
loanapproval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
loanapproval_df.describe()
# Out:
#            loan_id  no_of_dependents  income_annum   loan_amount    loan_term  \
# count  4269.000000       4269.000000  4.269000e+03  4.269000e+03  4269.000000
# mean   2135.000000          2.498712  5.059124e+06  1.513345e+07    10.900445
# std    1232.498479          1.695910  2.806840e+06  9.043363e+06     5.709187
# min       1.000000          0.000000  2.000000e+05  3.000000e+05     2.000000
# 25%    1068.000000          1.000000  2.700000e+06  7.700000e+06     6.000000
# 50%    2135.000000          3.000000  5.100000e+06  1.450000e+07    10.000000
# 75%    3202.000000          4.000000  7.500000e+06  2.150000e+07    16.000000
# max    4269.000000          5.000000  9.900000e+06  3.950000e+07    20.000000
#
#        cibil_score  residential_assets_value  commercial_assets_value  \
# count  4269.000000              4.269000e+03             4.269000e+03
# mean    599.936051              7.472617e+06             4.973155e+06
# ...

# %% [markdown]
# **Create Unclean dataset**

# %% [markdown]
# - Random insert NaN and abnormal values in to dataset, I will make it dirty by applying some code to demonstrate that I can do data cleaning processes.

# %%
df_createnotclean = loanapproval_df.copy()

# %%
for col in df_createnotclean.sample(n = np.random.randint(low = 5, high = 7, dtype=int), axis=1):
    df_createnotclean.loc[df_createnotclean.sample(frac = np.random.uniform(0.01, 0.02)).index, col] = np.nan

# %% [markdown]
# - Random insert abnormal values into this dataset, such as &,?, and @.

# %%
cols_list = df_createnotclean.sample(n = 2, axis=1).select_dtypes('object').columns.tolist()

for col in df_createnotclean[cols_list]:
    df_createnotclean.loc[df_createnotclean.sample(n = 50).index, col] = np.random.choice(['&', '?','@'])

# %% [markdown]
# - Check NaN values that I have been insert.

# %%
df_createnotclean.isnull().sum()
# Out:
# loan_id                      0
# no_of_dependents             0
# education                   51
# self_employed               67
# income_annum                78
# loan_amount                  0
# loan_term                    0
# cibil_score                 78
# residential_assets_value     0
# commercial_assets_value      0
# luxury_assets_value          0
# bank_asset_value            79
# loan_status                 53
# dtype: int64

# %% [markdown]
# - Save unclean file as .csv.

# %%
df_createnotclean.to_csv('Social_Media_Advertising_Notclean.csv') # index=False

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# The primary objective of this phase is to systematically clean the dataset. The initial steps involve re-reading the unclean data, performing a check for duplicate rows, and removing irrelevant columns. Subsequently, a thorough process is applied to handle both abnormal and missing values.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# The unclean dataset is read into a new DataFrame. An initial check for duplicate rows is performed to ensure each record is unique. With no duplicates found, the analysis can proceed. The loan_id column is then dropped, as it serves as a unique identifier rather than a predictive feature for the machine learning model.

# %% [markdown]
# ### Set up DataFrame, check DataFrame, and Basic EDA

# %% [markdown]
# - Read csv file that has been uploaded and save as original Pandas DataFrame

# %%
df_org = pd.read_csv("/kaggle/input/loan-approval-dataset-unclean/loan_approval_dataset_unclean.csv")

# %% [markdown]
# - Copy csv file and assign to file name 'df'

# %%
df = df_org.copy()

# %% [markdown]
# - Display all columns in DataFrame and top ten rows of DataFrame.

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0   29900000.0       12.0          778                   2400000
# 1   12200000.0        8.0          417                   2700000
# 2   29700000.0       20.0          506                   7100000
# 3   30700000.0        8.0          467                  18200000
# 4   24200000.0       20.0          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# ...

# %% [markdown]
# - Display all columns in DataFrame and last ten rows of DataFrame.

# %%
pd.set_option('display.max_columns', None)
df.tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# ...

# %% [markdown]
# - Check number of rows and columns in this dataset.

# %%
print('The shape of dataset is', df.shape)
# Out:
# The shape of dataset is (4269, 13)

# %% [markdown]
# - Checking and finding duplicate row in DataFrame by using .duplicated().sum(). It does not have duplicated row in this DataFrame

# %%
print('The duplicate rows in the dataset :', df.duplicated().sum())
# Out:
# The duplicate rows in the dataset : 0

# %% [markdown]
# **Type of data in each column in the dataset**

# %% [markdown]
# - Checking the basic information of DataFrame, which has the name of each column, number of non missing values in each column, and types of each column.

# %%
print('The data type of each columns of dataset : \n')
df.info()
# Out:
# The data type of each columns of dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4198 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4204 non-null   float64
#  6   loan_term                 4218 non-null   float64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4205 non-null   float64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4202 non-null   object
# ...

# %% [markdown]
# - The DataFrame has numerical columns and categorical columns.

# %% [markdown]
# **Basic Statistics of the dataset**

# %%
print('The Descriptive Statistics of Data : \n')
df.describe().T
# Out:
# The Descriptive Statistics of Data :
#                            count          mean           std       min  \
# loan_id                   4269.0  2.135000e+03  1.232498e+03       1.0
# no_of_dependents          4269.0  2.498712e+00  1.695910e+00       0.0
# income_annum              4269.0  5.059124e+06  2.806840e+06  200000.0
# loan_amount               4204.0  1.513501e+07  9.037534e+06  300000.0
# loan_term                 4218.0  1.089995e+01  5.718389e+00       2.0
# cibil_score               4269.0  5.999361e+02  1.724304e+02     300.0
# residential_assets_value  4269.0  7.472617e+06  6.503637e+06 -100000.0
# commercial_assets_value   4269.0  4.973155e+06  4.388966e+06       0.0
# luxury_assets_value       4205.0  1.511463e+07  9.107152e+06  300000.0
# bank_asset_value          4269.0  4.976692e+06  3.250185e+06       0.0
#
#                                 25%         50%         75%         max
# loan_id                      1068.0      2135.0      3202.0      4269.0
# ...

# %% [markdown]
# - In Basic Statistics, it shows basic statistics of numerical columns in the DataFrame that have count (number of rows), mean, standard deviation, min (minimize value of column), 25% (the lower percentile), 50% (median), 75% (the upper percentile), and max (maximize value of column).

# %% [markdown]
# ## Dealing with missing values and abnormal value in DataFrame

# %% [markdown]
# An analysis of the unique values within the categorical columns (education, self_employed, and loan_status) reveals two primary issues: the presence of leading spaces and the inclusion of an invalid & character.
#
# - Replacement of Invalid Characters: The & character is identified and replaced with a NaN value. This allows it to be handled as a missing value in the next step, ensuring data consistency.
#
# - Whitespace Removal: Leading spaces are systematically removed from all categorical values. This standardization is critical for accurate data analysis and proper function of machine learning algorithms.

# %% [markdown]
# ### Delete Unnecessary Column

# %% [markdown]
# - Deleting unnecessary column, which is not relevant to train machine learning model.

# %%
df = df.drop(['loan_id'], axis=1)
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# ...

# %% [markdown]
# **Re-Format of columns name**

# %% [markdown]
# - In this dataset, it contained space before name of each column, so I have to remove those space to easy to handle with this dataset.

# %%
df = df.rename(columns={' no_of_dependents':'no_of_dependents', ' education':'education', ' self_employed':'self_employed',
       ' income_annum':'income_annum', ' loan_amount':'loan_amount', ' loan_term':'loan_term', ' cibil_score':'cibil_score',
       ' residential_assets_value':'residential_assets_value', ' commercial_assets_value':'commercial_assets_value',
       ' luxury_assets_value':'luxury_assets_value', ' bank_asset_value':'bank_asset_value', ' loan_status':'loan_status'})

# %% [markdown]
# ## Dealing with abnormal value

# %% [markdown]
# **Finding Abnormal Values**

# %% [markdown]
# - Finding abnormal values that have differences from unique values in each column, then changing it to NaN value, so I can easily deal with it as missing value later on.

# %% [markdown]
# - Using for-loop .unique to find abnormal values in categorical column in DataFrame.

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.to_list()
for col in categorical_cols:
    print(f'Column name : {col}' )
    print(f'Unique value : {df[col].unique()}')
    print("------------------------------------------------------------------")
# Out:
# Column name : education
# Unique value : [' Graduate' ' Not Graduate' nan '&']
# ------------------------------------------------------------------
# Column name : self_employed
# Unique value : [' No' ' Yes']
# ------------------------------------------------------------------
# Column name : loan_status
# Unique value : [' Approved' ' Rejected' nan]
# ------------------------------------------------------------------

# %% [markdown]
# - In this dataset, it contained np.str_('&') in column loan_status, and space( ) before each values in categorical column of this dataset (education, self_employed, and loan_status).

# %% [markdown]
# **Replace abnormal value**

# %% [markdown]
# - Using .replace to replace & into NaN values in DataFrame

# %%
df.replace(to_replace = np.str_('&'), value= np.nan, inplace = True)

# %% [markdown]
# - Using for-loop to find abnormal values again to check abnormal, which had already replace with nan value in DataFrame.
# - All of abnormal values has been replace with nan values.

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.to_list()
for col in categorical_cols:
    print(f'Column name : {col}' )
    print(f'Unique value : {df[col].unique()}')
    print("------------------------------------------------------------------")
# Out:
# Column name : education
# Unique value : [' Graduate' ' Not Graduate' nan]
# ------------------------------------------------------------------
# Column name : self_employed
# Unique value : [' No' ' Yes']
# ------------------------------------------------------------------
# Column name : loan_status
# Unique value : [' Approved' ' Rejected' nan]
# ------------------------------------------------------------------

# %% [markdown]
# **Remove space of values in column**

# %% [markdown]
# - Remove space of categorical values, which is contained in column education, self_employed, and loan_status.

# %%
df['education'] = df['education'].str.replace(' Not Graduate', 'Not Graduate')
df['education'] = df['education'].str.replace(' Graduate','Graduate')
df['self_employed'] = df['self_employed'].str.replace(' Yes', 'Yes')
df['self_employed'] = df['self_employed'].str.replace(' No', 'No')
df['loan_status'] = df['loan_status'].str.replace(' Approved', 'Approved')
df['loan_status'] = df['loan_status'].str.replace(' Rejected', 'Rejected')

# %%
df['education'] = df['education'].str.replace('NotGraduate', 'Not Graduate')

# %% [markdown]
# - Re-check values in each column in DataFrame again.

# %%
categorical_cols = df.select_dtypes(include=['object']).columns.to_list()
for col in categorical_cols:
    print(f'Column name : {col}' )
    print(f'Unique value : {df[col].unique()}')
    print("------------------------------------------------------------------")
# Out:
# Column name : education
# Unique value : ['Graduate' 'Not Graduate' nan]
# ------------------------------------------------------------------
# Column name : self_employed
# Unique value : ['No' 'Yes']
# ------------------------------------------------------------------
# Column name : loan_status
# Unique value : ['Approved' 'Rejected' nan]
# ------------------------------------------------------------------

# %% [markdown]
# ## Dealing with missing values

# %% [markdown]
# **Imputation Strategies**

# %% [markdown]
# The dataset is found to have missing values across several columns. The approach to handling these missing values is determined by their distribution and the nature of the data.
#
# - Target Variable Imputation: The loan_status column is the target variable for the predictive model. Given the critical role of this feature, any rows with missing values in this column are dropped. This approach prevents distortion of the model's predictions, as imputing the target variable could lead to biased results. This action results in a loss of approximately 1.6% of the data, a small price for maintaining model integrity.
#
# - Missing Value Imputation for Categorical Features: The education column contains missing values. A visual inspection of its value distribution reveals a near-uniform split between 'Graduate' and 'Not Graduate' categories. Consequently, the missing values are imputed using the mode (the most frequent value). This method preserves the original distribution of the data without introducing bias.
#
# - Missing Value Imputation for Numerical Features: The numerical features loan_amount, loan_term, and luxury_assets_value also contain missing values. To determine the most appropriate imputation strategy, the skewness of each column's distribution is calculated.
#
#   - For loan_amount and luxury_assets_value, the data exhibits low skewness (<1), indicating a near-symmetrical distribution. Therefore, the mean is used to fill the missing values, as it is a robust measure of central tendency for such distributions.
#
#   - For loan_term, although the skewness is low, the values are discrete rather than continuous. To preserve the proportional distribution of the existing data, missing values are filled by randomly sampling from the unique values in the column, weighted by their frequency. This maintains the integrity of the data's original distribution.
#
# After all imputations, the final number of missing values is verified to confirm that the dataset is now complete.

# %% [markdown]
# - Checking basic information and total number of missing values to figure out how to deal with each column.

# %%
print('The missing valuse of dataset : \n', df.isnull().sum())
# Out:
# The missing valuse of dataset :
#  no_of_dependents              0
# education                   121
# self_employed                 0
# income_annum                  0
# loan_amount                  65
# loan_term                    51
# cibil_score                   0
# residential_assets_value      0
# commercial_assets_value       0
# luxury_assets_value          64
# bank_asset_value              0
# loan_status                  67
# dtype: int64

# %%
print('The missing valuse of train dataset : \n', df.isnull().sum())
# Out:
# The missing valuse of train dataset :
#  no_of_dependents              0
# education                   121
# self_employed                 0
# income_annum                  0
# loan_amount                  65
# loan_term                    51
# cibil_score                   0
# residential_assets_value      0
# commercial_assets_value       0
# luxury_assets_value          64
# bank_asset_value              0
# loan_status                  67
# dtype: int64

# %% [markdown]
# **Copy DataFrame and test drop all of NaN values**

# %% [markdown]
# - Test drop all of the missing values in DataFrame to check that how many percentage of the data tha is going to lost.

# %%
df_createnotclean_testdrop = df.copy()

# %% [markdown]
# - Drop all of missing values in each row in DataFrame by using .dropna and save to DataFrame (inplace = True), and then checking shape of DataFrame again.

# %%
df_createnotclean_testdrop.dropna(inplace = True)
df_createnotclean_testdrop.shape
# Out:
# (3917, 12)

# %% [markdown]
# - After drop all of missing value, the DataFrame has 3,917 rows, which calculated around 8 percent of data that is lost, so we have to dealing with these missing values by other ways.

# %% [markdown]
# **Visualizing Missing Values**

# %% [markdown]
# - There is five column, which contained NaN value, and I goin to visualize percentage of these missing values in each column.

# %%
print('The data type of each columns of dataset : \n')
df.info()
# Out:
# The data type of each columns of dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no_of_dependents          4269 non-null   int64
#  1   education                 4148 non-null   object
#  2   self_employed             4269 non-null   object
#  3   income_annum              4269 non-null   int64
#  4   loan_amount               4204 non-null   float64
#  5   loan_term                 4218 non-null   float64
#  6   cibil_score               4269 non-null   int64
#  7   residential_assets_value  4269 non-null   int64
#  8   commercial_assets_value   4269 non-null   int64
#  9   luxury_assets_value       4205 non-null   float64
#  10  bank_asset_value          4269 non-null   int64
#  11  loan_status               4202 non-null   object
# dtypes: float64(3), int64(6), object(3)
# ...

# %%
missing_ratio1 = df.isnull().sum() / len(df) * 100                                                        #First graph : Calculated percent of missing value

missing_df1 = pd.DataFrame({'column': missing_ratio1.index, 'missing_ratio': missing_ratio1.values})      #Change line above into DataFrame

plt.figure(figsize=(15, 6))                                                                               #Visualization by seaborn
plt.grid(True)                                                                                            #Add scale
ax1 = sns.barplot(x='column', y='missing_ratio', data=missing_df1, color='lightblue')

plt.xticks(rotation=45, ha='right')                                                                       #Set x-axis labels to column names (rotate to improve readability)
plt.title('Missing Values ratio of Dataset')

plt.yticks(range(0, 101, 20))                                                                             # Set y-axis labels
plt.ylabel('Missing Values ratio(%)')

for p in ax1.patches:                                                                                     # Percentage of missing values displayed above each bar
    height = p.get_height()
    ax1.text(p.get_x() + p.get_width() / 2.,
            height + 0.8,
            '{:.1f}%'.format(height),
            ha="center")
    sns.set_palette("pastel")

# Plot graph
plt.tight_layout()                                                                                        # Adjust the gap between two graphs
plt.show()

# %% [markdown]
# - Check percentage of missing values in each column

# %%
missing_df1
# Out:
#                       column  missing_ratio
# 0           no_of_dependents       0.000000
# 1                  education       2.834387
# 2              self_employed       0.000000
# 3               income_annum       0.000000
# 4                loan_amount       1.522605
# 5                  loan_term       1.194659
# 6                cibil_score       0.000000
# 7   residential_assets_value       0.000000
# 8    commercial_assets_value       0.000000
# 9        luxury_assets_value       1.499180
# 10          bank_asset_value       0.000000
# 11               loan_status       1.569454

# %% [markdown]
# - There are missing values in categorical and numerical columns in the DataFrame. Percent of missing value on each column is from one point two percent to two point eight percent in missing value columns.

# %% [markdown]
# **Missing value in Target column**

# %% [markdown]
# - For target column, I am going to drop all of NaN values in this column because if I fill NaN values in this column, it will make my prediction distorted.

# %%
df.dropna(subset=['loan_status'], inplace=True)
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                    2      Graduate            No       9600000   29900000.0
# 1                    0  Not Graduate           Yes       4100000   12200000.0
# 2                    3      Graduate            No       9100000   29700000.0
# 3                    3      Graduate            No       8200000   30700000.0
# ...

# %% [markdown]
# - After drop NaN values in this column, I have to reset index of this DataFrame.

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                    2      Graduate            No       9600000   29900000.0
# 1                    0  Not Graduate           Yes       4100000   12200000.0
# 2                    3      Graduate            No       9100000   29700000.0
# 3                    3      Graduate            No       8200000   30700000.0
# ...

# %% [markdown]
# - Re-check NaN values in Target column after drop missing values.

# %%
print('The missing valuse of dataset : \n', df.isnull().sum())
# Out:
# The missing valuse of dataset :
#  no_of_dependents              0
# education                   118
# self_employed                 0
# income_annum                  0
# loan_amount                  64
# loan_term                    51
# cibil_score                   0
# residential_assets_value      0
# commercial_assets_value       0
# luxury_assets_value          64
# bank_asset_value              0
# loan_status                   0
# dtype: int64

# %% [markdown]
# **Missing value in Education column**

# %% [markdown]
# - To figure out how to deal with missing value in categorical column, I have to plot histogram to see distribution of data.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['education'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='education', ylabel='Count'>

# %%
df['education'].value_counts()
# Out:
# education
# Graduate        2051
# Not Graduate    2033
# Name: count, dtype: int64

# %% [markdown]
# - The missing values in the education column exhibit a distribution with nearly equal proportions for the 'Graduate' and 'Not Graduate' categories. Due to this balanced distribution, and with the 'Graduate' category having a slightly higher frequency, the most appropriate imputation strategy is to replace the missing values with the mode (the most frequent value).
#
# - Before performing this imputation, a copy of the DataFrame is created to serve as a backup. This measure ensures that the original data can be preserved in case any errors occur during the data cleaning process, allowing for a return to the original state without the need to reload the dataset.

# %%
df_impute = df.copy()                                                             # Creates a copy of the DataFrame

# %%
df_impute.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000   29900000.0
# 1                 0  Not Graduate           Yes       4100000   12200000.0
# 2                 3      Graduate            No       9100000   29700000.0
# 3                 3      Graduate            No       8200000   30700000.0
# 4                 5  Not Graduate           Yes       9800000   24200000.0
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0       12.0          778                   2400000                 17600000
# 1        8.0          417                   2700000                  2200000
# 2       20.0          506                   7100000                  4500000
# 3        8.0          467                  18200000                  3300000
# 4       20.0          382                  12400000                  8200000
#
# ...

# %% [markdown]
# **Remark :** Libraries are imported at the beginning of the script to ensure all necessary functions and modules are available and to improve code readability and organization. This practice allows for a clear overview of the project's dependencies.

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# - Impute NaN values with mode by using simple imputer.

# %%
mode_imputer = SimpleImputer(strategy='most_frequent')                          # Most frequent imputation
df_imputed = pd.DataFrame(mode_imputer.fit_transform(df_impute[['education']]))
df_imputed.shape
# Out:
# (4202, 1)

# %% [markdown]
# - Assign filled missing value back into main DataFrame.

# %%
df['education'] = df_imputed

# %% [markdown]
# - Count unique values after filling missing value.

# %%
df['education'].value_counts()
# Out:
# education
# Graduate        2169
# Not Graduate    2033
# Name: count, dtype: int64

# %% [markdown]
# - Plot histogram to check distribution after filling missing value.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['education'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='education', ylabel='Count'>

# %% [markdown]
# - Check number of NaN value in the column after filled it.

# %%
df.isnull().sum()
# Out:
# no_of_dependents             0
# education                    0
# self_employed                0
# income_annum                 0
# loan_amount                 64
# loan_term                   51
# cibil_score                  0
# residential_assets_value     0
# commercial_assets_value      0
# luxury_assets_value         64
# bank_asset_value             0
# loan_status                  0
# dtype: int64

# %% [markdown]
# **Dealing with missing values in Numerical column**

# %% [markdown]
# - Checking skewness of numerical column by using for-loop, .skew, and histogram before filling missing value.

# %%
for i in ['loan_amount','loan_term','luxury_assets_value']:
    print(i , df[i].skew())
    print('----------------------------------------------------------------------------')
# Out:
# loan_amount 0.3167590849230923
# ----------------------------------------------------------------------------
# loan_term 0.03190824640176431
# ----------------------------------------------------------------------------
# luxury_assets_value 0.3266055510216899
# ----------------------------------------------------------------------------

# %% [markdown]
# **Dealing with missing value in loan_amount column**

# %% [markdown]
# - In this column, it should fill with mean beacuse skewness of the data is less than 1.

# %% [markdown]
# - Plot histogram to see dirstribution of data in column.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['loan_amount'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_amount', ylabel='Count'>

# %% [markdown]
# - The distribution of this data is right-skew distribution, so it should fill with mean.

# %%
mean = df['loan_amount'].mean()
df['loan_amount'].fillna(mean, inplace=True)
# Out:
# /tmp/ipykernel_122/3728447252.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['loan_amount'].fillna(mean, inplace=True)

# %% [markdown]
# - Plot histogram to check distribution after fill missing values.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['loan_amount'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_amount', ylabel='Count'>

# %% [markdown]
# - Re-check missing value in column after filled the missing value into column.

# %%
df.isnull().sum()
# Out:
# no_of_dependents             0
# education                    0
# self_employed                0
# income_annum                 0
# loan_amount                  0
# loan_term                   51
# cibil_score                  0
# residential_assets_value     0
# commercial_assets_value      0
# luxury_assets_value         64
# bank_asset_value             0
# loan_status                  0
# dtype: int64

# %% [markdown]
# **Dealing with missing value in loan_term column**

# %% [markdown]
# - Plot histogram to see distribution of data in the column.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['loan_term'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_term', ylabel='Count'>

# %% [markdown]
# - The data exhibits a right-skewed distribution. However, given that the values in this column are discrete rather than continuous, imputation with the mean is not an appropriate strategy as it may introduce non-existent data points and distort model predictions. Therefore, missing values will be imputed proportionally based on the frequency distribution of the existing values in the raw dataset.
#
# - The distribution of each unique value within the categorical columns was analyzed by calculating the percentage of each unique value. This was done to assess the balance of the dataset's categorical features.

# %% [markdown]
# - Checking percentage of each unique value for categorical column.

# %%
value_counts = df.loan_term.value_counts(normalize=True).mul(100)
df_value_counts = pd.DataFrame(value_counts)
sorted_df_loan_termB = df_value_counts.sort_values(by='proportion', ascending=False)
sorted_df_loan_termB
# Out:
#            proportion
# loan_term
# 6.0         11.491207
# 12.0        10.720308
# 4.0         10.383040
# 10.0        10.142134
# 18.0         9.853047
# 20.0         9.708504
# 16.0         9.660323
# 2.0          9.588051
# 14.0         9.563960
# 8.0          8.889424

# %% [markdown]
# - After determining the proportional frequency of each unique value, these proportions were used to generate a list that serves as a probability distribution. This list was then used to systematically impute the missing values in the column, ensuring that the distribution of the imputed data remained consistent with the observed distribution of the raw dataset.

# %%
value_counts = df.loan_term.value_counts(normalize=True).astype(float)
df_value_counts = pd.DataFrame(value_counts)
sorted_df_loan_term = df_value_counts.sort_values(by='proportion', ascending=False)
sorted_df_loan_term
# Out:
#            proportion
# loan_term
# 6.0          0.114912
# 12.0         0.107203
# 4.0          0.103830
# 10.0         0.101421
# 18.0         0.098530
# 20.0         0.097085
# 16.0         0.096603
# 2.0          0.095881
# 14.0         0.095640
# 8.0          0.088894

# %% [markdown]
# - Filling missing value based on unique values and proportion of each unique values in column.

# %%
uniqueva = sorted_df_loan_term.index.unique().tolist()
prob = sorted_df_loan_term['proportion'].tolist()

df['loan_term'] = df['loan_term'].fillna(pd.Series(np.random.choice(uniqueva, p= prob, size=len(df)), index=df.index))

# %% [markdown]
# - After imputation, the distribution of the unique values in the column was re-examined to confirm that the proportional integrity was maintained. This was achieved by applying the same code used for the initial percentage check prior to filling the missing values.

# %%
value_counts = df.loan_term.value_counts(normalize=True).mul(100)
df_value_counts = pd.DataFrame(value_counts)
sorted_df_loan_termA = df_value_counts.sort_values(by='proportion', ascending=False)
sorted_df_loan_termA
# Out:
#            proportion
# loan_term
# 6.0         11.494526
# 12.0        10.732984
# 4.0         10.471204
# 10.0        10.138030
# 18.0         9.828653
# 20.0         9.733460
# 16.0         9.638267
# 14.0         9.566873
# 2.0          9.543075
# 8.0          8.852927

# %% [markdown]
# - Re-check the distribution of unique values after filling missing values by using histogram.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['loan_term'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_term', ylabel='Count'>

# %% [markdown]
# **Dealing with missing valu in luxury_assets_value column**

# %% [markdown]
# - To address the missing values within the luxury_assets_value column, a mean imputation strategy was chosen. This approach is justified by the data's low skewness, which is a value less than 1, indicating a distribution that is sufficiently close to symmetrical. Using the mean as the imputation value minimizes the distortion of the central tendency and preserves the overall distribution of the dataset for this specific feature.

# %% [markdown]
# - Plot histogram to see dirstribution of data in column.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['luxury_assets_value'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxury_assets_value', ylabel='Count'>

# %% [markdown]
# - The data's distribution is observed to be right-skewed. Consequently, the mean will be used to impute missing values. While the mean can be sensitive to outliers in highly skewed data, this approach is deemed acceptable for its ability to maintain the overall central tendency of the dataset.

# %%
mean = df['luxury_assets_value'].mean()
df['luxury_assets_value'].fillna(mean, inplace=True)
# Out:
# /tmp/ipykernel_122/1806117749.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['luxury_assets_value'].fillna(mean, inplace=True)

# %% [markdown]
# - Plot histogram to check distribution after fill missing values.

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data=df['luxury_assets_value'], bins='auto', color = 'lightskyblue')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxury_assets_value', ylabel='Count'>

# %% [markdown]
# - Re-check missing value in column after filled the missing value into column.

# %%
df.isnull().sum()
# Out:
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %% [markdown]
# ### Detect Outlier and dealing with Outlier

# %% [markdown]
# Outliers in a dataset can significantly influence the performance of machine learning models. A standard method for detecting outliers is using boxplots, which visually represent the interquartile range (IQR).
#
# Boxplots for the numerical features residential_assets_value, commercial_assets_value, and bank_asset_value reveal the presence of outliers. However, instead of immediately removing or capping these values, a different strategy is employed. The final model will be trained using Robust Scaling, a method that scales features based on the median and the IQR. By setting the quantile_range to (20,80), this technique naturally mitigates the impact of outliers without the need for manual intervention, thus preserving all available data.

# %% [markdown]
# - Check information of our DataFrame for name of numerical column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no_of_dependents          4202 non-null   int64
#  1   education                 4202 non-null   object
#  2   self_employed             4202 non-null   object
#  3   income_annum              4202 non-null   int64
#  4   loan_amount               4202 non-null   float64
#  5   loan_term                 4202 non-null   float64
#  6   cibil_score               4202 non-null   int64
#  7   residential_assets_value  4202 non-null   int64
#  8   commercial_assets_value   4202 non-null   int64
#  9   luxury_assets_value       4202 non-null   float64
#  10  bank_asset_value          4202 non-null   int64
#  11  loan_status               4202 non-null   object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 394.1+ KB

# %% [markdown]
# - Create a box plot for each numerical column to visualize the outlier in
# each numerical column.
# - In this dataset, there is an outlier in Increase_Sales column. It can be seen by several dots on the graph out of the minimum and maximum range, as in the in the picture in the attached link below.

# %% [markdown]
# **Outlier Information** : [see Outlier Information](https://builtin.com/data-science/boxplot)

# %% [markdown]
# - Use for-loop to plot boxplot for numerical column in the DataFrame.

# %%
for i in df.select_dtypes(include = "number").columns :
    plt.figure(figsize=(15, 8))
    sns.boxplot(data = df, x = i)
    plt.show()
    print()
    print()
    print('-'*150)
    print()
    print()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# - Outliers were identified in the residential_assets_value, commercial_assets_value, and bank_asset_value columns. These outliers were visually detected on the left side of their respective box plots, indicating data points that fall below the minimum range defined by the plot's whiskers.
# - Credit for formalur and code are from the website below.

# %% [markdown]
# **Outlier Code Credit** : [see Outlier Code Credit](https://medium.com/@datasciencejourney100_83560/how-to-handle-outliers-in-a-dataset-data-cleaning-exploratory-data-analysis-1fd0bf7f7d60)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# This section provides an overview of the dataset's features, including their distributions and the relationships between them. This analysis is crucial for gaining insights into the data, informing feature engineering decisions, and selecting appropriate modeling techniques. All libraries are imported at the beginning of the code for clear dependency management.
#
# **Feature Distribution**
#
# The distribution of each feature is examined to inform the choice of scaling and encoding methods, assess the need for oversampling, and determine an appropriate train-test split for model training.
#
# **Numerical Features**
#
# A histogram is used to visualize the distribution of each numerical feature. The analysis reveals the following distributions:
# - Left-Skewed: no_of_dependents, loan_amount
# - Uniform: income_annum, cibil_score
# - Right-Skewed: loan_term, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value
#
# **Categorical Features**
#
# Bar plots are used to visualize the distribution of unique values for each categorical feature. The distributions of the education and self_employed columns are relatively balanced, while the loan_status column is imbalanced. This imbalance in the target variable (loan_status) suggests that oversampling may be necessary before training a model to prevent bias toward the majority class.

# %% [markdown]
# **Correlation Analysis**
#
# A correlation analysis is performed to identify the relationships between features. A heatmap is generated using the Pearson correlation coefficient after all categorical variables have been Label Encoded to allow for a comprehensive analysis across both numerical and categorical data types.
#
# The analysis reveals that most features have a low correlation with the target variable, loan_status. However, cibil_score has a notable negative correlation, indicating that a higher credit score is associated with a lower likelihood of a loan being rejected. Despite the overall low correlations, no features will be dropped at this stage, as even weak relationships may contribute to the predictive power of the final model.

# %% [markdown]
# **Feature Relationships**
#
# Scatter plots are used to visually inspect the relationships between a few of the most highly correlated features:
# - luxury_assets_value and bank_asset_value: The plots indicate a strong positive correlation, suggesting that individuals with high-value luxury assets also tend to have a high bank asset value.
# - residential_assets_value and commercial_assets_value: This pair shows a moderate positive relationship. The plots also reveal that most people have low values for both assets, with loan approvals and rejections distributed equally in this range.
# - loan_amount and income_annum: A strong positive correlation is observed between these two features, which is expected, as individuals with higher annual incomes are typically approved for larger loan amounts.

# %% [markdown]
# ## Distribution of features

# %% [markdown]
# - Check the distribution of each feature because it can provide intuitions about which scaling and encode should we use for this dataset, should we do oversampling, and how much data should be split to train and test the models for the objective of the model.

# %% [markdown]
# **Summary all of the distribution of nummerical variable**

# %% [markdown]
# - Check dirstribution of data set by using histogram

# %%
numerical_cols = df.select_dtypes(include=['number']).columns.to_list()                      # Separate numerical columns

# Create a figure with subplots
num_cols = len(numerical_cols)
num_rows = (num_cols + 2) // 3                                                               # Calculate the number of rows in subplots
fig, axes = plt.subplots(nrows = num_rows, ncols = 3, figsize=(25, 7 * num_rows))
axes = axes.flatten()                                                                        # Flatten the axes array for easy iteration

# Plot chart
for i, col in enumerate(numerical_cols):
    axes[i].hist(df[col], bins=20, edgecolor='black',color= "darkturquoise")
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

# Hide any unused subplots
for i in range(num_cols, num_rows * 3):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of each column is :
# - no_of_dependents : left-skewed distribution
# - income_annum : uniform distribution
# - loan_amount : left-skewed distribution
# - loan_term : right-skewed distribution
# - cibil_score : uniform distribution
# - residential_assets_value : right-skewed distribution
# - commercial_assets_value : right-skewed distribution
# - luxury_assets_value : right-skewed distribution
# - bank_asset_value : right-skewed distribution

# %% [markdown]
# **Summary all of the distribution of categorical variable**

# %%
# Separate categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns.to_list()

# Create a figure with subplots
fig, axes = plt.subplots(ncols = 3, figsize=(20, 6))

# Flatten the axes array for easy iteration
axes = axes.flatten()

colors = ['lightcoral','turquoise']

for i, col in enumerate(categorical_cols):
    value_counts = df[col].value_counts()
    axes[i].bar(value_counts.index, value_counts.values, color=colors)
    axes[i].set_title(f'{col} Counts')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')


plt.tight_layout()
plt.show()

# %% [markdown]
# - From the histogram above, it can be seen that the unique values in education and self_employed are nearly equal (balance classes), but the loan status column is not equal (imbalance classes).

# %% [markdown]
# **Above Code Credit** : [see Code Credit I](https://saturncloud.io/blog/how-to-plot-multiple-graphs-in-a-for-loop-with-ipythonjupyter-notebook-and-pandas/)

# %% [markdown]
# **Above Code Credit** : [see Code Credit II](https://matplotlib.org/3.1.1/gallery/subplots_axes_and_figures/figure_title.html)

# %% [markdown]
# **Above Code Credit** : [see Code Credit III](https://matplotlib.org/stable/gallery/color/named_colors.html)

# %% [markdown]
# ## Distribution of Target labels

# %% [markdown]
# **Check proportion of unique value**

# %% [markdown]
# - An analysis of the target variable revealed a significant class imbalance. To address this issue and ensure robust model performance, an oversampling technique was applied to the training data before the model was trained.

# %%
plt.figure(figsize=(15, 8))
plt.title('Distribution of loan status ')
plt.xlabel('loan status')
sns.histplot(data=df['loan_status'], bins='auto', color = 'darkturquoise')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Distribution of loan status '}, xlabel='loan status', ylabel='Count'>

# %%
df['loan_status'].value_counts(normalize=True)*100
# Out:
# loan_status
# Approved    62.089481
# Rejected    37.910519
# Name: proportion, dtype: float64

# %% [markdown]
# ## Correlation analysis

# %% [markdown]
# - Analysis of correlation between each feature in DataFrame. By this way, we can drop unnecessary features that are not necessary for our model (the feature that has a low correlation with the target label).

# %% [markdown]
# **Find correlation between variable**

# %% [markdown]
# - Use label encode to encode categorical data in the DataFrame, and then plot a heat map to see the correlation between each feature.

# %% [markdown]
# - Copy another DataFrame to prepared to encode the DataFrame.

# %%
df_corr_check_labelencode = df.copy()

# %% [markdown]
# - Use Label Encoding to encode all of categorical features in this DataFrame, and then plot correlation matrix.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()                                                             # Label Encoding the ordinal categorical variable
df_corr_check_labelencode['education'] = le.fit_transform(df_corr_check_labelencode['education'])
df_corr_check_labelencode['self_employed'] = le.fit_transform(df_corr_check_labelencode['self_employed'])
df_corr_check_labelencode['loan_status'] = le.fit_transform(df_corr_check_labelencode['loan_status'])

correlation_matrix_labeledncode = df_corr_check_labelencode.corr()              # Compute correlation between numerical and encoded categorical
correlation_matrix_labeledncode
# Out:
#                           no_of_dependents  education  self_employed  \
# no_of_dependents                  1.000000  -0.003482       0.002701
# education                        -0.003482   1.000000       0.030803
# self_employed                     0.002701   0.030803       1.000000
# income_annum                      0.003807  -0.010574       0.006490
# loan_amount                      -0.008347  -0.008659       0.000045
# loan_term                        -0.015218   0.019874       0.000995
# cibil_score                      -0.010784   0.009669      -0.005402
# residential_assets_value          0.003110  -0.012608       0.009720
# commercial_assets_value          -0.003189   0.006267      -0.013674
# luxury_assets_value               0.001708  -0.013933       0.011735
# bank_asset_value                  0.009698  -0.006378       0.001657
# loan_status                       0.018499  -0.002671      -0.000452
#
# ...

# %% [markdown]
# - Visualize correlation between each variable by using heatmap.

# %%
# Create the heatmap
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(correlation_matrix_labeledncode, annot=True, cmap='coolwarm', center=0)

# Show the plot
plt.title('Correlation Heatmap Label Encode')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %% [markdown]
# - From correlation matrix, every feature in this DataFrame seen to have less correlation with the target variable. However, it has one feature (cibil_score) that has a negative correlation with the target variable, but I am not going to drop it because it may somehow be useful for the model to predict the result of the model.

# %% [markdown]
# ## Plot scatter plot to see correlation between high correlation features

# %% [markdown]
# **Relationship Between luxury assets value and bank asset value**

# %%
plt.figure(figsize=(10, 8))  # Set the figure size
sns.scatterplot(x= df['luxury_assets_value'], y= df['bank_asset_value'], hue=df['loan_status'])
plt.title("Relationship Between Luxury Assets Value and Bank Asset Value")
plt.xlabel("Bank Asset Value")
plt.ylabel("Luxury Assets Value")
plt.show()

# %%
sns.relplot(df, x=df['luxury_assets_value'], y=df['bank_asset_value'], col="loan_status", hue="loan_status", style="loan_status", kind="scatter")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - From the chart, it can be inferred that people with high bank assets also have high luxury assets.

# %% [markdown]
# **Relationship residential assets value and commercial assets value**

# %%
plt.figure(figsize=(10, 8))  # Set the figure size
sns.scatterplot(x=df['residential_assets_value'], y= df['commercial_assets_value'], hue= df['loan_status'])
plt.title("Relationship residential assets value and commercial assets value")
plt.xlabel("residential assets value")
plt.ylabel("commercial assets value")
plt.show()

# %%
sns.relplot(df, x=df['residential_assets_value'], y=df['commercial_assets_value'], col="loan_status", hue="loan_status", style="loan_status", kind="scatter")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - From the chart, it can be inferred that most people have low residential assets and commercial assets, both of them get equal approve and reject in the same proportion.

# %% [markdown]
# **Relationship between annual income and loan amount by loan amount**

# %%
plt.figure(figsize=(10, 8))  # Set the figure size
sns.scatterplot(x= df['loan_amount'], y= df['income_annum'], hue=df['loan_status'])
plt.title("Relationship Between Annual Income and Loan Amount")
plt.xlabel("Loan Amount")
plt.ylabel("Annual Income")
plt.show()

# %%
sns.relplot(df, x=df['loan_amount'], y=df['income_annum'], col="loan_status", hue="loan_status", style="loan_status", kind="scatter")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - From the chart, it can be inferred that people with high loan amounts also get high loan amounts, and this pair of correlations has a really strong correlation.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Change unit value of some column

# %% [markdown]
# - Change unit values in column loan_term from year to day, which could increase the accuracy of the model more than in the year unit.

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000   29900000.0
# 1                 0  Not Graduate           Yes       4100000   12200000.0
# 2                 3      Graduate            No       9100000   29700000.0
# 3                 3      Graduate            No       8200000   30700000.0
# 4                 5  Not Graduate           Yes       9800000   24200000.0
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0       12.0          778                   2400000                 17600000
# 1        8.0          417                   2700000                  2200000
# 2       20.0          506                   7100000                  4500000
# 3        8.0          467                  18200000                  3300000
# 4       20.0          382                  12400000                  8200000
#
# ...

# %%
df['loan_term'] = df['loan_term'] * 365

# %% [markdown]
# ## Encoding categorical attributes

# %% [markdown]
# - Machine learning models are designed to operate on numerical data. Therefore, it is a necessary preprocessing step to encode categorical attributes before training. For this project, one-hot encoding was selected for this task. This method is particularly suitable because the categorical columns in the dataset contain only binary unique values, and the values within each column, such as 'graduate' and 'not graduate,' are inherently correlated. One-hot encoding effectively transforms these attributes into a numerical format that is compatible with machine learning algorithms.

# %% [markdown]
# - Copy DataFrame from main DataFrame to prepared to encode.

# %%
df_loanstatus = df.copy()

# %%
df_loanstatus.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000   29900000.0
# 1                 0  Not Graduate           Yes       4100000   12200000.0
# 2                 3      Graduate            No       9100000   29700000.0
# 3                 3      Graduate            No       8200000   30700000.0
# 4                 5  Not Graduate           Yes       9800000   24200000.0
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0     4380.0          778                   2400000                 17600000
# 1     2920.0          417                   2700000                  2200000
# 2     7300.0          506                   7100000                  4500000
# 3     2920.0          467                  18200000                  3300000
# 4     7300.0          382                  12400000                  8200000
#
# ...

# %% [markdown]
# - Take only categorical data from copy DataFrame (drop all of numerical column in the DataFrame).

# %%
categorical_cols = ['education', 'self_employed', 'loan_status']
df_cat = df_loanstatus[categorical_cols]
df_cat
# Out:
#          education self_employed loan_status
# 0         Graduate            No    Approved
# 1     Not Graduate           Yes    Rejected
# 2         Graduate            No    Rejected
# 3         Graduate            No    Rejected
# 4     Not Graduate           Yes    Rejected
# ...            ...           ...         ...
# 4197      Graduate           Yes    Rejected
# 4198  Not Graduate           Yes    Approved
# 4199  Not Graduate            No    Rejected
# 4200  Not Graduate            No    Approved
# 4201      Graduate            No    Approved
#
# [4202 rows x 3 columns]

# %% [markdown]
# - Import one-hot encoding library.

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# - The provided categorical features were encoded using the fit_transform command on the training data. The sparse_output=False parameter was specified to ensure the output was a dense array, which is often a more convenient data structure for subsequent processing and model training than a sparse matrix.

# %%
categorical_cols = ['education', 'self_employed', 'loan_status']
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')                           # sparse_output=False to prevent sparse matrix
encoded_array = encoder.fit_transform(df_loanstatus[categorical_cols])                          # Fit and transform the categorical column
df_cat = pd.DataFrame(encoded_array, columns=encoder.get_feature_names_out(categorical_cols))   # Convert the encoded array back into a DataFrame with proper column names
df_cat
# Out:
#       education_Graduate  education_Not Graduate  self_employed_No  \
# 0                    1.0                     0.0               1.0
# 1                    0.0                     1.0               0.0
# 2                    1.0                     0.0               1.0
# 3                    1.0                     0.0               1.0
# 4                    0.0                     1.0               0.0
# ...                  ...                     ...               ...
# 4197                 1.0                     0.0               0.0
# 4198                 0.0                     1.0               0.0
# 4199                 0.0                     1.0               1.0
# 4200                 0.0                     1.0               1.0
# 4201                 1.0                     0.0               1.0
#
#       self_employed_Yes  loan_status_Approved  loan_status_Rejected
# 0                   0.0                   1.0                   0.0
# ...

# %% [markdown]
# - During data preprocessing, it was necessary to drop redundant categorical columns. Specifically, after applying one-hot encoding, I selected only the columns representing the "yes" category for each binary feature and removed the corresponding "no" columns to avoid multicollinearity. Subsequently, the encoded columns were renamed for clarity and assigned to a new DataFrame. This DataFrame was then prepared to be merged with the scaled numerical data, creating a comprehensive feature set for the machine learning model.

# %%
df_cat = df_cat[['education_Graduate','self_employed_Yes','loan_status_Approved']]
df_cat.rename(columns={'education_Graduate':'education','self_employed_Yes':'self_employed','loan_status_Approved':'loan_status'}, inplace=True)
df_cat
# Out:
# /tmp/ipykernel_122/3016602208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.rename(columns={'education_Graduate':'education','self_employed_Yes':'self_employed','loan_status_Approved':'loan_status'}, inplace=True)
#       education  self_employed  loan_status
# 0           1.0            0.0          1.0
# 1           0.0            1.0          0.0
# 2           1.0            0.0          0.0
# 3           1.0            0.0          0.0
# 4           0.0            1.0          0.0
# ...         ...            ...          ...
# 4197        1.0            1.0          0.0
# 4198        0.0            1.0          1.0
# 4199        0.0            0.0          0.0
# 4200        0.0            0.0          1.0
# 4201        1.0            0.0          1.0
#
# ...

# %% [markdown]
# - Assign encode column back to encode DataFrame.

# %%
df_encode = df_loanstatus
df_encode[['education', 'self_employed', 'loan_status']] = df_cat[['education', 'self_employed', 'loan_status' ]]
df_encode
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2        1.0            0.0       9600000   29900000.0
# 1                    0        0.0            1.0       4100000   12200000.0
# 2                    3        1.0            0.0       9100000   29700000.0
# 3                    3        1.0            0.0       8200000   30700000.0
# 4                    5        0.0            1.0       9800000   24200000.0
# ...                ...        ...            ...           ...          ...
# 4197                 5        1.0            1.0       1000000    2300000.0
# 4198                 0        0.0            1.0       3300000   11300000.0
# 4199                 2        0.0            0.0       6500000   23900000.0
# 4200                 1        0.0            0.0       4100000   12800000.0
# 4201                 1        1.0            0.0       9200000   29700000.0
#
# ...

# %% [markdown]
# ## Scaling features

# %% [markdown]
# The Robust Scaler was selected for data scaling due to the financial nature of the dataset, which includes columns such as annual income and asset values. These features are prone to containing extreme outliers. The Robust Scaler is particularly effective in such cases because it utilizes the interquartile range to normalize the data, making it less susceptible to the influence of outliers compared to other methods.
#
# Other scaling methods were deemed unsuitable for this dataset for the following reasons:
#
# - Min-Max Scaling: This method is not appropriate as it is highly sensitive to outliers, which can distort the scaled data.
# - Standardization (Z-Score Scaling): This technique, while effective for normally distributed data, was not chosen because the distributions of the features in this dataset do not conform to a Gaussian distribution.
# - MaxAbs Scaling: This method was also ruled out as it is primarily designed for datasets containing both positive and negative values, which is not a characteristic of the financial features in this dataset.

# %% [markdown]
# - Create table, which contains all of nummerical columns from main DataFrame.

# %%
numerical_cols = ['no_of_dependents', 'income_annum',
       'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
       'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',]
df_num = df_loanstatus[numerical_cols]
df_num
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000   29900000.0     4380.0          778
# 1                    0       4100000   12200000.0     2920.0          417
# 2                    3       9100000   29700000.0     7300.0          506
# 3                    3       8200000   30700000.0     2920.0          467
# 4                    5       9800000   24200000.0     7300.0          382
# ...                ...           ...          ...        ...          ...
# 4197                 5       1000000    2300000.0     5110.0          317
# 4198                 0       3300000   11300000.0     7300.0          559
# 4199                 2       6500000   23900000.0     6570.0          457
# 4200                 1       4100000   12800000.0     2920.0          780
# 4201                 1       9200000   29700000.0     3650.0          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %% [markdown]
# - Import RobustScaler for scaling data

# %%
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# - The numerical columns in the DataFrame were scaled using the Robust Scaler. To more effectively address the presence of outliers in the residential_assets_value, commercial_assets_value, and bank_asset_value columns, the quantile range was modified from its default of (25, 75) to (20, 80). This adjustment expands the range used for normalization, thereby reducing the influence of extreme values and helping to mitigate the risk of overfitting by limiting noise introduced by these outliers.

# %%
scaler = RobustScaler(quantile_range=(20, 80))
scaler.fit(df_num)
df_num = pd.DataFrame(scaler.transform(df_num),columns=df_num.columns)
df_num
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0            -0.333333      0.775862     0.893491   0.172414     0.498879
# 1            -1.000000     -0.172414    -0.153846  -0.172414    -0.512892
# 2             0.000000      0.689655     0.881657   0.862069    -0.263453
# 3             0.000000      0.534483     0.940828  -0.172414    -0.372758
# 4             0.666667      0.810345     0.556213   0.862069    -0.610987
# ...                ...           ...          ...        ...          ...
# 4197          0.666667     -0.706897    -0.739645   0.344828    -0.793161
# 4198         -1.000000     -0.310345    -0.207101   0.862069    -0.114910
# 4199         -0.333333      0.241379     0.538462   0.689655    -0.400785
# 4200         -0.666667     -0.172414    -0.118343  -0.172414     0.504484
# 4201         -0.666667      0.706897     0.881657   0.000000     0.019619
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %% [markdown]
# - Assign scaling a numerical DataFrame to encode DataFrame that we already assigned encoded categorical columns into it.

# %%
df_encode[numerical_cols] = df_num[numerical_cols]
df_encode
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0            -0.333333        1.0            0.0      0.775862     0.893491
# 1            -1.000000        0.0            1.0     -0.172414    -0.153846
# 2             0.000000        1.0            0.0      0.689655     0.881657
# 3             0.000000        1.0            0.0      0.534483     0.940828
# 4             0.666667        0.0            1.0      0.810345     0.556213
# ...                ...        ...            ...           ...          ...
# 4197          0.666667        1.0            1.0     -0.706897    -0.739645
# 4198         -1.000000        0.0            1.0     -0.310345    -0.207101
# 4199         -0.333333        0.0            0.0      0.241379     0.538462
# 4200         -0.666667        0.0            0.0     -0.172414    -0.118343
# 4201         -0.666667        1.0            0.0      0.706897     0.881657
#
# ...

# %% [markdown]
# - Re-check descriptive statistics to make sure all of the columns are encoded and scaling.

# %%
df_encode.describe().round(1).T
# Out:
#                            count  mean  std  min  25%  50%  75%  max
# no_of_dependents          4202.0  -0.2  0.6 -1.0 -0.7  0.0  0.3  0.7
# education                 4202.0   0.5  0.5  0.0  0.0  1.0  1.0  1.0
# self_employed             4202.0   0.5  0.5  0.0  0.0  1.0  1.0  1.0
# income_annum              4202.0  -0.0  0.5 -0.8 -0.4  0.0  0.4  0.8
# loan_amount               4202.0   0.0  0.5 -0.9 -0.4  0.0  0.4  1.5
# loan_term                 4202.0   0.1  0.5 -0.7 -0.3  0.0  0.5  0.9
# cibil_score               4202.0  -0.0  0.5 -0.8 -0.4  0.0  0.4  0.8
# residential_assets_value  4202.0   0.2  0.6 -0.5 -0.3  0.0  0.5  2.0
# commercial_assets_value   4202.0   0.2  0.6 -0.5 -0.3  0.0  0.5  2.0
# luxury_assets_value       4202.0   0.0  0.5 -0.8 -0.4  0.0  0.4  1.4
# bank_asset_value          4202.0   0.1  0.6 -0.8 -0.4  0.0  0.4  1.7
# loan_status               4202.0   0.6  0.5  0.0  0.0  1.0  1.0  1.0

# %% [markdown]
# ## Split the data

# %% [markdown]
# Data splitting is a critical step in the machine learning workflow to prepare for model training and evaluation. To ensure the model's performance can be accurately assessed on unseen data, the dataset was partitioned into a training set and a testing set.

# %% [markdown]
# - Import library for split the data

# %%
import sklearn.model_selection

# %% [markdown]
# - The train_test_split function from the sklearn.model_selection library was used to perform this task. An 80 : 20 split was implemented, allocating 80% of the data to the training set for model learning and the remaining 20% to the testing set for validation. The resulting shapes of the split datasets were then verified to confirm the correct proportions.

# %%
df_encode_train, df_encode_test = sklearn.model_selection.train_test_split(df_encode, test_size=0.2)
print("DataFrame Loanstatus Train:", df_encode_train.shape)
print("DataFrame Loanstatus Test:", df_encode_test.shape)
# Out:
# DataFrame Loanstatus Train: (3361, 12)
# DataFrame Loanstatus Test: (841, 12)

# %% [markdown]
# - Following the initial split, the training and testing datasets were further separated into feature variables (x) and the target variable (y). The feature variables, which are the independent features used for prediction, were denoted as x_train x_test. The target variable, the dependent feature to be predicted, was designated as y_train and y_test. The shapes of these resulting subsets were subsequently examined to ensure the integrity of the data structure.

# %%
x_train = df_encode_train.drop(["loan_status"], axis=1)
y_train = df_encode_train["loan_status"]
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print('-------------------------------------------------------------------------')
x_test = df_encode_test.drop(["loan_status"], axis=1)
y_test = df_encode_test["loan_status"]
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (3361, 11)
# y_train: (3361,)
# -------------------------------------------------------------------------
# x_test: (841, 11)
# y_test: (841,)

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# For this project, Linear Discriminant Analysis (LDA) was selected as the dimensionality reduction technique. This method was chosen because the dataset contains categorical features, and LDA is particularly effective at identifying and preserving information that maximizes the separability between different classes.
#
# In contrast, Principal Component Analysis (PCA) was not utilized as it is primarily suited for datasets with purely numerical features and focuses on maximizing variance, rather than class distinction.
#
# Furthermore, applying dimensionality reduction helps to reduce model complexity, thereby mitigating the risk of overfitting.

# %% [markdown]
# - Import LDA function

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %% [markdown]
# - The Linear Discriminant Analysis (LDA) model was applied to both the training and testing datasets. The n_components parameter was set to 1, reducing the dimensionality of the feature set to a single component. This step was performed on both the training and testing data to ensure consistent feature representation for subsequent model training and evaluation.

# %%
lda = LDA(n_components=1)                                                       # Reduce to 1 component
x_train = lda.fit_transform(x_train, y_train)
x_test = lda.fit_transform(x_test, y_test)
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
# Out:
# x_train: (3361, 1)
# x_test: (841, 1)

# %% [markdown]
# ## Oversampling

# %% [markdown]
# In this section, I will address the class imbalance observed in the target variable, as previously visualized in the histogram plot. To mitigate this issue, the Synthetic Minority Over-sampling Technique (SMOTE) will be applied. SMOTE is a robust oversampling method that generates synthetic data points for the minority class, thereby balancing the dataset and improving the model's ability to learn from and accurately predict the underrepresented class.

# %% [markdown]
# **Theory Behind Oversampling (SMOTE)**
#
# Class imbalance is a common challenge in machine learning, where the number of instances in one class significantly outweighs the instances in other classes. This can cause a model to become biased toward the majority class, leading to poor predictive performance on the minority class. To address this issue, oversampling techniques are used to artificially increase the number of instances in the minority class, thereby balancing the dataset.
#
# The Synthetic Minority Over-sampling Technique (SMOTE) is a popular oversampling algorithm. Instead of simply duplicating existing instances, SMOTE generates new, synthetic data points for the minority class. It works by:
# - Selecting a random instance from the minority class.
# - Finding its k-nearest neighbors (where 'k' is a user-defined parameter) in the feature space.
# - Generating a new, synthetic instance at a random point along the line segments connecting the selected instance and its neighbors.
#
# This process creates new data that is a blend of existing minority class instances, expanding the decision boundary of the minority class.
#
# **Application**
#
# In this section, the SMOTE algorithm will be applied to address the class imbalance in the target variable, as previously identified by the histogram plot. This process will create a more balanced training dataset, enabling the model to learn from both the majority and minority classes more effectively and improving its overall generalization performance.

# %%
import imblearn.over_sampling

# %% [markdown]
# - Apply oversampling (SMOTE) with x train and y train.

# %%
os = imblearn.over_sampling.SMOTE()
x_train, y_train = os.fit_resample(x_train, y_train)
y_train.value_counts()
# Out:
# loan_status
# 1.0    2077
# 0.0    2077
# Name: count, dtype: int64

# %% [markdown]
# # Train Model

# %% [markdown]
# This chapter focuses on the training and evaluation of a series of machine learning models for classification. After training, each model was evaluated using K-fold cross-validation to identify the most suitable candidate for subsequent hyperparameter tuning.
#
# The models selected for this analysis include:
#
# - Machine Learning Model
#   - Logistic Regression
#   - Naive Bayes
#   - Support Vector Machine
#   - K-Nearest Neighbor
#   - Decision Tree
#
# - Ensemble Learning Model
#   - Random Forest Classifier
#   - Gradient Boosting Classifier
#   - eXtreme Gradient Boosting (XGBoost)
#   - LightGBM

# %% [markdown]
# ## Theoretical Background

# %% [markdown]
# **K-Fold Cross-Validation**
#
# K-fold cross-validation is a robust technique used to evaluate a model's performance and generalization ability. The process involves partitioning the entire dataset into K equal-sized folds. The model is then trained K times. In each iteration, a unique fold is reserved as the validation set, while the remaining K-1 folds are used for training. The performance metric is calculated for each of the K validation runs, and the final performance of the model is reported as the average of these K scores. This method provides a more reliable estimate of a model's performance on unseen data by reducing the variance associated with a single train-test split. K-Fold Cross-Validation is implemented by using cross_val_score from tensorflow library.
#
# **Classification Models**
#
# - Logistic Regression: A linear model used for binary classification. It estimates the probability of a data point belonging to a particular class by fitting a logistic function to the data.
#
# - Naive Bayes: Based on Bayes' theorem, this is a probabilistic classifier that assumes a strong (naive) independence between features. It's often used for tasks like spam filtering and text classification due to its simplicity and efficiency.
#
# - Support Vector Machine (SVM): A model that finds the optimal hyperplane in a high-dimensional space to separate data points into different classes. It aims to maximize the margin between the classes to improve classification accuracy.
#
# - K-Nearest Neighbor (k-NN): A non-parametric, instance-based learning algorithm. It classifies a new data point by a majority vote of its k nearest neighbors, where k is a user-defined integer. The class assigned is the most common among its neighbors.
#
# - Decision Tree: A tree-like model that makes decisions by splitting the data into subsets based on the most significant features. The goal is to create a tree with clear, distinct leaf nodes that represent the final classification.
#
# **Ensemble Learning Models**
#
# - Random Forest Classifier: An ensemble method that operates by constructing multiple decision trees during training. For classification, the output is the class chosen by the majority of the trees. It reduces overfitting by creating randomness in feature and data selection for each tree.
#
# - Gradient Boosting Classifier: An ensemble technique that builds a series of weak learners (typically decision trees) sequentially. Each new tree corrects the errors of its predecessor, and the final prediction is a weighted sum of the predictions from all the trees.
#
# - eXtreme Gradient Boosting (XGBoost): An optimized and highly efficient implementation of gradient boosting. It is known for its speed and performance and includes regularization techniques to prevent overfitting.
#
# - LightGBM: An open-source gradient-boosting framework that uses a tree-based learning algorithm. It is designed to be highly efficient and scalable, particularly for large datasets, by using a technique called Gradient-based One-Side Sampling (GOSS).

# %% [markdown]
# ## Machine Learning Model

# %% [markdown]
# - Import necessary modules

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **Logistics Regression Model**

# %% [markdown]
# - Import module

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_logistics = LogisticRegression()
model_logistics.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
cv = cross_val_score(model_logistics, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.93301435 0.92105263 0.92822967 0.92822967 0.92326139 0.94004796
#  0.92326139 0.93285372 0.94004796 0.92326139]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9293260128739114
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Naive Bayes**

# %% [markdown]
# - Import module

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_naive_bayes = GaussianNB()
model_naive_bayes.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
cv = cross_val_score(model_naive_bayes, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.9354067  0.92583732 0.92822967 0.93062201 0.93045564 0.94724221
#  0.92086331 0.9352518  0.94004796 0.92326139]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9317217995938177
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Support Vector Machine**

# %% [markdown]
# - Import module

# %%
import sklearn.svm

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_svm = sklearn.svm.SVC()
model_svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
cv_svm = cross_val_score(model_svm, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv_svm)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv_svm.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.93301435 0.92822967 0.92822967 0.93062201 0.93285372 0.94964029
#  0.92086331 0.9352518  0.93764988 0.92326139]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9319616077472951
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **K-Nearest Neighbor**

# %% [markdown]
# - Import module

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_knn = KNeighborsClassifier()
model_knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
cv_knn = cross_val_score(model_knn, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv_knn)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv_knn.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.91626794 0.9138756  0.92583732 0.92822967 0.90407674 0.9352518
#  0.92086331 0.9352518  0.93285372 0.92086331]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9233371197778618
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Decision Tree**

# %% [markdown]
# - Import module

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_decision_tree = DecisionTreeClassifier()
model_decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
cv_decision_tree = cross_val_score(model_decision_tree, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv_decision_tree)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv_decision_tree.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.88755981 0.86602871 0.89952153 0.8923445  0.882494   0.90167866
#  0.91606715 0.92086331 0.91846523 0.90407674]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.89890996293874
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Ensemble Learning Model

# %% [markdown]
# Ensemble learning is a powerful machine learning paradigm where multiple models, known as "base learners," are trained to solve the same problem. The predictions from these individual models are then combined to produce a more accurate and robust final prediction than any single model could achieve on its own. The core principle is that a diverse group of "weak learners" can collectively form a "strong learner" by mitigating individual errors and biases. There are several key ensemble methods, with bagging (e.g., Random Forest) and boosting (e.g., Gradient Boosting, XGBoost, LightGBM) being the most prominent.
#
# - Bagging (Bootstrap Aggregating): This method involves training multiple base models independently on different subsets of the data, which are created by sampling with replacement (bootstrapping). The final prediction is determined by averaging the predictions (for regression) or taking a majority vote (for classification). The randomness in the data sampling helps to reduce variance and prevent overfitting.
#
# - Boosting: In contrast to bagging, boosting builds models sequentially. Each new model is trained to correct the errors made by the previous models. This process gives more weight to misclassified instances, forcing subsequent models to focus on the most difficult parts of the data. This approach is highly effective at reducing bias.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# **Gradient Boosting Classifier**

# %% [markdown]
# - Import module

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
model_gradient_boost = GradientBoostingClassifier()
model_gradient_boost.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
cv = cross_val_score(model_gradient_boost, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.92344498 0.91626794 0.91866029 0.92344498 0.92326139 0.92565947
#  0.91846523 0.94004796 0.93764988 0.91606715]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9242969260954872
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Random Forest Classifier**

# %% [markdown]
# - Import module

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
random_forest_model = RandomForestClassifier()
random_forest_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
cv = cross_val_score(random_forest_model, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.88995215 0.86602871 0.89952153 0.8923445  0.882494   0.90167866
#  0.91606715 0.92086331 0.91846523 0.90407674]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.8991491973885009
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **eXtreme Gradient Boosting (XGBoost)**

# %% [markdown]
# - Import module

# %%
from xgboost import XGBClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
XGB_model = XGBClassifier()
XGB_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
cv = cross_val_score(XGB_model, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.92822967 0.92344498 0.93062201 0.92822967 0.92086331 0.94004796
#  0.92086331 0.93045564 0.94244604 0.92326139]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9288463965669569
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **LightGBM**

# %% [markdown]
# - Import module

# %%
from lightgbm import LGBMClassifier

# %% [markdown]
# - Train the model by using x train and y train dataset.

# %%
LGB_model = LGBMClassifier(verbose=-1)
LGB_model.fit(x_train, y_train)
# Out:
# LGBMClassifier(verbose=-1)

# %%
cv = cross_val_score(LGB_model, x_train, y_train, cv=10, scoring='accuracy')
print("K-Fold Cross-Validation:", cv)
print('-'*100)
print(f'Average K-Fold Cross-Validation: {cv.mean()}')
print('-'*100)
# Out:
# K-Fold Cross-Validation: [0.92344498 0.92105263 0.92822967 0.93062201 0.91127098 0.9352518
#  0.93045564 0.9352518  0.94244604 0.91846523]
# ----------------------------------------------------------------------------------------------------
# Average K-Fold Cross-Validation: 0.9276490769107204
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# **Theoretical Background**
#
# Hyperparameter tuning is a crucial step in the machine learning workflow that aims to optimize a model's performance. Unlike model parameters, which are learned from the data (e.g., coefficients in a linear model), hyperparameters are external configuration settings that are set prior to the training process (e.g., the number of neighbors in k-NN or the learning rate in a boosting model). The goal of tuning is to find the combination of hyperparameters that yields the best possible performance on unseen data, thereby achieving the model's objective, such as maximizing accuracy or minimizing error.
#
# One of the most common and systematic methods for hyperparameter tuning is a grid search. In a grid search, a predefined grid of hyperparameter values is created, and the model is trained and evaluated for every possible combination of values in the grid. This exhaustive search guarantees that the best combination of values within the specified range is found. While computationally expensive, it is a reliable method for exploring the parameter space.

# %% [markdown]
# ## Algorithm selection

# %% [markdown]
# - A for loop was implemented to systematically calculate the cross-validation scores for each model. This iterative approach facilitates a direct comparison of the individual fold scores and, more importantly, the average cross-validation score for each model. The model with the highest average score was then selected for the next phase of the project: hyperparameter tuning using a grid search. This method ensures that the most promising models are advanced, optimizing computational resources and project efficiency.

# %% [markdown]
# - Create variable for for-loop to prepared to train and calculate K-Fold Cross-Validation and average K-Fold Cross-Validation of all models.

# %%
ml_models = [("Logistic Regression" , LogisticRegression()),
             ("Naive Bayes" , GaussianNB()),
             ("SVM" , sklearn.svm.SVC()),
             ("KNN" , KNeighborsClassifier()),
             ("Decision Tree" , DecisionTreeClassifier()),
             ("Gradient Boosting Classifier", GradientBoostingClassifier()),
             ("Random Forest Classifier" , RandomForestClassifier()),
             ("XGBoost" , XGBClassifier()),
             ("LightGBM" , LGBMClassifier(verbose=-1))]

# %% [markdown]
# - Use for-loop to train calculate K-Fold Cross-Validation and average K-Fold Cross-Validation of all models, and then select two models to do hyperparameter tuning by using grid search.

# %%
for model in ml_models:
    print(model[0]+": ")
    model[1].fit(x_train, y_train)
    cv = cross_val_score(model[1], x_train, y_train, cv=10, scoring='accuracy')
    print("\tK-Fold Cross-Validation:", cv)
    print('-'*100)
    print(f'\tAverage K-Fold Cross-Validation: {cv.mean()}')
    print('-'*100)
# Out:
# Logistic Regression:
# 	K-Fold Cross-Validation: [0.93301435 0.92105263 0.92822967 0.92822967 0.92326139 0.94004796
#  0.92326139 0.93285372 0.94004796 0.92326139]
# ----------------------------------------------------------------------------------------------------
# 	Average K-Fold Cross-Validation: 0.9293260128739114
# ----------------------------------------------------------------------------------------------------
# Naive Bayes:
# 	K-Fold Cross-Validation: [0.9354067  0.92583732 0.92822967 0.93062201 0.93045564 0.94724221
#  0.92086331 0.9352518  0.94004796 0.92326139]
# ----------------------------------------------------------------------------------------------------
# 	Average K-Fold Cross-Validation: 0.9317217995938177
# ----------------------------------------------------------------------------------------------------
# SVM:
# 	K-Fold Cross-Validation: [0.93301435 0.92822967 0.92822967 0.93062201 0.93285372 0.94964029
#  0.92086331 0.9352518  0.93764988 0.92326139]
# ...

# %% [markdown]
# - From result, it can be seen that two models that have the highest average Cross-Validation are Support Vector Machine and eXtreme Gradient Boosting (XGBoost), so I going to take these two models to do grid search.
# - Based on the analysis of the cross-validation results, the models with the highest average scores were the Support Vector Machine and eXtreme Gradient Boosting (XGBoost). Consequently, these two models have been selected for a detailed hyperparameter tuning process using a grid search.
# - The decision to select the Support Vector Machine (SVM) over the Naive Bayes model, despite their similar cross-validation scores, was guided by the Scikit-Learn Algorithm Selection Diagram and the specific objectives of the project. SVM is a more direct approach for this business task, as it is well-suited to support and generalize to new, unseen datasets in the future

# %% [markdown]
# ## Hyperparameter tuning (Grid Search) and Model Validation

# %% [markdown]
# **Hyperparameter tuning (Grid Search)**

# %%
from sklearn.model_selection import GridSearchCV
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Support Vector Machine

# %% [markdown]
# **Theory Behind Support Vector Machine Hyperparameters**
#
# Support Vector Machines (SVMs) are powerful models used for both classification and regression. The performance of an SVM is highly dependent on its hyperparameters, which allow for fine-tuning the model's behavior and complexity. These parameters control the trade-off between fitting the training data accurately and maintaining a simple, generalizable model.

# %% [markdown]
# **Important Parameters**
#
# **C (Regularization Parameter):**
#
# The C parameter is a positive value that controls the penalty for misclassified training data points. It represents a trade-off between achieving a smooth decision boundary and correctly classifying all training points.
# - Small C: A small C value places less emphasis on correctly classifying individual data points. This results in a wider margin and a simpler, smoother decision boundary, which can reduce overfitting and improve generalization on unseen data.
# - Large C: A large C value penalizes misclassifications more heavily, forcing the model to fit the training data as accurately as possible. This can lead to a narrower margin and a more complex decision boundary, which may result in overfitting.
#
# **Kernel:**
#
# The kernel is a function that transforms the input data into a higher-dimensional feature space. This allows the model to find a linear decision boundary even when the original data is not linearly separable. The choice of kernel is crucial as it determines the nature of the decision boundary.
# - linear: Uses a linear function to create a straight decision boundary. This is suitable for data that is linearly separable.
# - rbf (Radial Basis Function): Also known as the Gaussian kernel, it is effective for non-linear data. It maps data to an infinite-dimensional space, creating a complex, non-linear decision boundary.
# - poly (Polynomial): Creates a non-linear decision boundary by using a polynomial function of a specified degree.
# - sigmoid: Uses a sigmoid function and is a popular choice in neural networks.
#
# **gamma:**
#
# The gamma parameter, a kernel coefficient, is used with the rbf, poly, and sigmoid kernels. It defines the influence of a single training example on the model's decision boundary.
# - Low gamma: A low gamma value means a large influence radius, causing points farther away from the decision boundary to be considered. This results in a smoother, less complex model.
# - High gamma: A high gamma value means a small influence radius, causing only points very close to the decision boundary to be considered. This can lead to a highly complex, "spiky" decision boundary that may overfit the training data.
#
# **degree:**
#
# This parameter is exclusively used for the poly kernel and represents the degree of the polynomial function. A higher degree allows the model to fit more complex, curved relationships in the data.
#
# **coef0:**
#
# This is an independent term in the kernel function, which is relevant only for the poly and sigmoid kernels. It is used to adjust the model's sensitivity to high-dimensional data.
#
# **tol (Tolerance):**
#
# The tol parameter specifies the tolerance for the stopping criterion. The model will stop training when the change in the objective function is less than this value.

# %% [markdown]
# Set hyperparameters for Grid Search :

# %% [markdown]
#     - 'C' : [0.01, 0.1, 1, 10]                         # range from 0.1 to find the best fit for the model
#     - 'kernel': ['linear', 'rbf', 'poly', 'sigmoid']   # search for the best function from every type of s
#     - 'gamma': [0.01, 0.1, 1]                          # cover all type of gamma that will be possible for model
#     - 'degree': [2, 3]                                 # degree of polynomial function
#     - 'coef0': [0.0, 0.1, 1],                          # Only relevant for 'poly' and 'sigmoid' kernels
#     - 'tol': [1e-3, 1e-4, 1e-5]                        # Tolerance for stopping criterion

# %%
hyperpara_grid_svm = {
    'C': [0.01, 0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'gamma': [0.01, 0.1, 1],
    'degree': [2, 3],
    'coef0': [0.0, 0.1, 1], # Only relevant for 'poly' and 'sigmoid' kernels
    'tol': [1e-3, 1e-4, 1e-5] # Tolerance for stopping criterion
    }

# %% [markdown]
# **Grid Search Parameter Configuration**
#
# The grid search was configured with the following parameters to systematically explore the hyperparameter space and identify the optimal model configuration:
#
# - cv (Cross-Validation): A value of 10 was assigned to this parameter, indicating that the dataset would be partitioned into 10 folds for cross-validation. This approach ensures a robust evaluation by training and validating the model across various data subsets, which provides a more reliable estimate of its performance and reduces the risk of overfitting to a single data split.
# - scoring: The scoring metric was set to accuracy. This choice is appropriate for this classification task where both positive (Approved) and negative (Rejected) classes are equally important to predict correctly. While the grid search can also evaluate other metrics like precision, recall, and F1-score, accuracy was chosen as the primary metric for comparison.
# - verbose: This parameter was set to 1 to control the level of verbosity during the model fitting process. This setting provides concise output from the grid search, displaying only the essential information about the progress of the fitting process. Values such as 0 (no output) and higher values (2, 3, etc.) provide increasing levels of detail.
# - n_jobs: The parameter was set to -1 to leverage all available CPU cores. This setting enables parallel processing, which significantly reduces the computational time required for the grid search, as it allows multiple hyperparameter combinations to be evaluated concurrently.

# %%
from sklearn.svm import SVC
# Initialize the SVM model
SVM_model = SVC()

# Set up GridSearchCV for hyperparameter tuning
grid_SVM = GridSearchCV(estimator=SVM_model,
                        param_grid=hyperpara_grid_svm,
                        cv=5,
                        scoring='accuracy',
                        verbose=1,
                        n_jobs=-1
                       )

# Fit the model with GridSearchCV
grid_SVM.fit(x_train, y_train)

# Print Results
print("\n--- SVM Hyperparameter Tuning Results ---")
print(f"Best Hyperparameters for SVM: {grid_SVM.best_params_}")
print(f"Best Cross-Validation Accuracy for SVM: {grid_SVM.best_score_:.2f}")
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
#
# --- SVM Hyperparameter Tuning Results ---
# Best Hyperparameters for SVM: {'C': 1, 'coef0': 0.0, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf', 'tol': 0.001}
# Best Cross-Validation Accuracy for SVM: 0.93

# %% [markdown]
# Hyperparameters for XGBoost model from grid search are :
# - 'C': 1
# - 'coef0': 0.0
# - 'degree': 2
# - 'gamma': 0.1
# - 'kernel': 'rbf'
# - 'tol': 0.001
#
# Accuracy for the model with these hyperparameter is 93.00 percent.

# %% [markdown]
# ### eXtreme Gradient Boosting (XGBoost)

# %% [markdown]
# **Theory Behind eXtreme Gradient Boosting (XGBoost)**
#
# eXtreme Gradient Boosting (XGBoost) is a highly efficient and scalable implementation of the gradient boosting framework. At its core, XGBoost is an ensemble learning method that builds a series of weak learners, typically decision trees, in a sequential manner. Each new tree is constructed to correct the errors of the previously built trees. This process is optimized through several key enhancements:
#
# - **Regularization:** XGBoost includes both L1 (Lasso) and L2 (Ridge) regularization terms in its objective function. This helps to prevent overfitting by penalizing complex models and encouraging simpler, more generalizable trees.
# - **Parallelism:** Unlike traditional boosting algorithms, XGBoost can parallelize the tree-building process, making it significantly faster and more scalable, especially on large datasets.
# - **Handling Missing Values:** XGBoost has a built-in mechanism to handle missing values by automatically learning the best direction to send a data point with a missing value.
# - **Smarter Splits:** It employs a more precise method for finding the optimal split points in a tree, leading to better-performing models.

# %% [markdown]
# **Important Hyperparameters for Grid Search**
#
# The following hyperparameters are crucial for tuning an XGBoost model and were selected for the grid search:
# - **n_estimators:** This parameter determines the number of boosting rounds or trees to be built. A higher value can improve performance but increases the risk of overfitting.
# - **max_depth:** This controls the maximum depth of each tree. A deeper tree can model more complex relationships but may lead to overfitting, while a shallower tree can cause underfitting.
# - **eta (learning rate):** The learning rate determines the step size at each boosting iteration. A smaller eta requires more boosting rounds but can lead to a more robust model.
# - **subsample:** This specifies the fraction of the training instances that will be randomly sampled for each tree. It can help reduce variance and prevent overfitting.
# - **colsample_bytree:** This controls the fraction of features that will be randomly sampled for each tree. A lower value can help prevent overfitting by making the trees more diverse.
# - **gamma:** This parameter sets the minimum loss reduction required to make a further partition on a leaf node. A larger gamma results in a more conservative algorithm.
# - **reg_alpha (L1 regularization):** This adds a penalty to the objective function proportional to the absolute value of the coefficients. A larger value makes the model more conservative, helping to prevent overfitting.
# - **reg_lambda (L2 regularization):** This adds a penalty to the objective function proportional to the square of the coefficients. Similar to reg_alpha, a larger value makes the model more conservative.

# %% [markdown]
# **Credit for parameter XGBoost** : [see Credit for parameter XGBoost](https://medium.com/@rithpansanga/the-main-parameters-in-xgboost-and-their-effects-on-model-performance-4f9833cac7c)

# %% [markdown]
# - Set hyperparameters for Grid Search :

# %% [markdown]
#     - 'n_estimators': [100, 200, 300],         # Number of tree for model
#     - 'max_depth': [3, 5, 7],                  # Max depth of a tree
#     - 'learning_rate': [0.01, 0.1 ,0.2],       # Set up as small, medium, and large value
#     - 'subsample': [0.5, 0.7],                 # Set up as small and large value
#     - 'colsample_bytree': [0.8, 1.0],          # Set up as small and large value
#     - 'gamma': [0, 0.1, 0.2],                  # Minimum loss function, set up as small, medium and large
#     - 'reg_alpha': [0, 0.1],                   # L1 regularization
#     - 'reg_lambda': [1, 1.5]                   # L2 regularization

# %%
hyperpara_grid_XGB = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1 ,0.2],
    'subsample': [0.5, 0.7],
    'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 0.1, 0.2],
    'reg_alpha': [0, 0.1],
    'reg_lambda': [1, 1.5]
    }

# %% [markdown]
# **Grid Search Parameter Configuration**
#
# The grid search was configured with the following parameters to systematically explore the hyperparameter space and identify the optimal model configuration:
#
# - cv (Cross-Validation): A value of 10 was assigned to this parameter, indicating that the dataset would be partitioned into 10 folds for cross-validation. This approach ensures a robust evaluation by training and validating the model across various data subsets, which provides a more reliable estimate of its performance and reduces the risk of overfitting to a single data split.
# - scoring: The scoring metric was set to accuracy. This choice is appropriate for this classification task where both positive (Approved) and negative (Rejected) classes are equally important to predict correctly. While the grid search can also evaluate other metrics like precision, recall, and F1-score, accuracy was chosen as the primary metric for comparison.
# - verbose: This parameter was set to 1 to control the level of verbosity during the model fitting process. This setting provides concise output from the grid search, displaying only the essential information about the progress of the fitting process. Values such as 0 (no output) and higher values (2, 3, etc.) provide increasing levels of detail.
# - n_jobs: The parameter was set to -1 to leverage all available CPU cores. This setting enables parallel processing, which significantly reduces the computational time required for the grid search, as it allows multiple hyperparameter combinations to be evaluated concurrently.

# %%
# Set off the model
XGB_model = XGBClassifier()
# Set off Grid Search
grid_XGB = GridSearchCV(estimator=XGB_model, 
                        param_grid=hyperpara_grid_XGB,     # Grid Search and Cross Validation
                        cv=5, 
                        scoring='accuracy', 
                        verbose=1, 
                        n_jobs=-1
                       )

# Fit the model with GridSearchCV
grid_XGB.fit(x_train, y_train)

# Display output the best parameters
print("\n--- SVM Hyperparameter Tuning Results ---")
print(f"Best Hyperparameters: {grid_XGB.best_params_}")
print(f"Best Cross-Validation Accuracy: {grid_XGB.best_score_}")
# Out:
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
#
# --- SVM Hyperparameter Tuning Results ---
# Best Hyperparameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.7}
# Best Cross-Validation Accuracy: 0.9314806358506009

# %% [markdown]
# Hyperparameters for XGBoost model from grid search are :
# - 'colsample_bytree': 0.8
# - 'gamma': 0.1
# - 'learning_rate': 0.1
# - 'max_depth': 3
# - 'n_estimators': 100
# - 'reg_alpha': 0.1
# - 'reg_lambda': 1
# - 'subsample': 0.7
#
# Accuracy for these hyperparameter is 93.15 percent.

# %% [markdown]
# **Select the best model for this task**

# %% [markdown]
# According from Grid Search, XGBoost Classifier model is selected as the best model for this task because accuracy from K-fold cross validation is higher than Support Vector Machine Model.

# %% [markdown]
# **Re-search for the better hyperparameter**

# %% [markdown]
# - Re-seach for the better hyperparameter for XGBoost Classifier model with grid search

# %% [markdown]
# Set hyperparameter grid:
# - 'colsample_bytree' =  0.8, which can set up for next iteration to do grid search as 0.7, 0.8, 0.9
# - 'gamma' = 0.1, which can set up for next iteration to do grid search as 0.1 ,0.2, 0.3
# - 'learning_rate' = 0.1, which can set up for next iteration to do grid search as 0.05 , 0.1, 0.15
# - 'max_depth' =  3, which can set up for next iteration to do grid search as 4, 3, 5.
# - 'n_estimators' = 100, which can set up for next iteration to do grid search as 50, 100, 150
# - 'reg_alpha' =  0.1, which can set up for next iteration to do grid search as 0.1, 0.2, 0.3
# - 'reg_lambda' =  1, which can set up for next iteration to do grid search as 0.5, 1, 1.5
# - 'subsample' = 0.7, which can set up for next iteration to do grid search as 0.5, 0.6, 0.7, 0.8

# %%
hyperpara_grid_XGB = {
    'n_estimators': [50, 100, 150],
    'max_depth': [4, 3, 5],
    'learning_rate': [0.05 , 0.1, 0.15],
    'subsample': [0.5, 0.6, 0.7, 0.8],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'gamma': [0.1 ,0.2, 0.3],
    'reg_lambda': [0.5, 1, 1.5],
    'reg_alpha': [0.1, 0.2, 0.3]
    }

# %% [markdown]
# **Grid Search Parameter Configuration**
#
# The grid search was configured with the following parameters to systematically explore the hyperparameter space and identify the optimal model configuration:
#
# - cv (Cross-Validation): A value of 10 was assigned to this parameter, indicating that the dataset would be partitioned into 10 folds for cross-validation. This approach ensures a robust evaluation by training and validating the model across various data subsets, which provides a more reliable estimate of its performance and reduces the risk of overfitting to a single data split.
# - scoring: The scoring metric was set to accuracy. This choice is appropriate for this classification task where both positive (Approved) and negative (Rejected) classes are equally important to predict correctly. While the grid search can also evaluate other metrics like precision, recall, and F1-score, accuracy was chosen as the primary metric for comparison.
# - verbose: This parameter was set to 1 to control the level of verbosity during the model fitting process. This setting provides concise output from the grid search, displaying only the essential information about the progress of the fitting process. Values such as 0 (no output) and higher values (2, 3, etc.) provide increasing levels of detail.
# - n_jobs: The parameter was set to -1 to leverage all available CPU cores. This setting enables parallel processing, which significantly reduces the computational time required for the grid search, as it allows multiple hyperparameter combinations to be evaluated concurrently.

# %%
# Set off the model
XGB_model = XGBClassifier()
# Set off Grid Search
grid_XGB = GridSearchCV(estimator=XGB_model, 
                        param_grid=hyperpara_grid_XGB,     # Grid Search and Cross Validation
                        cv=5, 
                        scoring='accuracy', 
                        verbose=1, 
                        n_jobs=-1)
# Fit the model with GridSearchCV
grid_XGB.fit(x_train, y_train)

# Print Results
print("\n--- SVM Hyperparameter Tuning Results ---")
print(f"Best Hyperparameters: {grid_XGB.best_params_}")
print(f"Best Cross-Validation Accuracy: {grid_XGB.best_score_}")
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
#
# --- SVM Hyperparameter Tuning Results ---
# Best Hyperparameters: {'colsample_bytree': 0.7, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.5}
# Best Cross-Validation Accuracy: 0.9422252185637859

# %% [markdown]
# The better hyperparameters for XGBoost model from grid search are :
# - 'colsample_bytree': 0.7
# - 'gamma': 0.1
# - 'learning_rate': 0.1
# - 'max_depth': 5
# - 'n_estimators': 100
# - 'reg_alpha': 0.1
# - 'reg_lambda': 1
# - 'subsample': 0.5
#
# Accuracy for these hyperparameter is 94.22 percent.

# %% [markdown]
# # Model Assessment

# %% [markdown]
# After the data has been thoroughly preprocessed and a suitable model has been selected, it is essential to train the model and evaluate its performance. The initial training is performed with default hyperparameters, followed by a Grid Search to identify the optimal set of parameters for improved performance. The model is then retrained using these optimal parameters.
#
# **Model Assessment**
#
# The final assessment of the model's performance is a critical step in the machine learning workflow. Given that this is a classification model, the evaluation metrics must be chosen accordingly. Metrics commonly used for regression tasks, such as Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared (R2), are not suitable for this problem.
#
# Instead, the model's performance will be evaluated using a comprehensive suite of classification metrics:
#
# - **Confusion Matrix:** This visual summary of the prediction results shows the number of correct and incorrect predictions for each class, providing insights into the types of errors the model is making.
# - **Accuracy, Precision, Recall, and F1-Score:** These metrics provide a holistic view of the model's predictive capability.
#   - Accuracy measures the overall proportion of correct predictions.
#   - Precision measures the proportion of positive identifications that were actually correct.
#   - Recall measures the proportion of actual positives that were identified correctly.
#   - The F1-Score is the harmonic mean of precision and recall, providing a balanced measure of the model's performance, especially in cases of class imbalance.
#
# **Cost-Sensitive Accuracy**
#
# This metric is particularly useful when the costs of different types of errors are not equal. It allows for an evaluation that weights certain mistakes more heavily, aligning the model's performance with real-world business objectives.
#
# **ROC Curve and Area Under the Curve (AUC)**
#
# The Receiver Operating Characteristic (ROC) curve plots the true positive rate against the false positive rate at various threshold settings. The Area Under the Curve (AUC) provides a single value representing the model's ability to distinguish between the positive and negative classes across all possible thresholds. A higher AUC value indicates a better-performing model.

# %% [markdown]
# ## Re-train the model

# %% [markdown]
# Following the identification of optimal hyperparameters through a grid search, the model is re-trained with these parameters to ensure the best possible performance. The best hyperparameters for the XGBoost model were found to be:
#
# - colsample_bytree: 0.7
# - gamma: 0.1
# - learning_rate: 0.1
# - max_depth: 5
# - n_estimators: 100
# - reg_alpha: 0.1
# - reg_lambda: 1
# - subsample: 0.5

# %%
# --- Train the final model with the best hyperparameters ---

# The most common approach is to use the best estimator found by GridSearchCV,
# which has already been trained on the full dataset.

# The `best_estimator_` attribute provides a fully trained model with the optimal parameters.

# You can also manually create a new model instance using the best_params_
# as shown in the original code, but using best_estimator_ is often more direct.
XGB_model_betterV = grid_XGB.best_estimator_

# Note: grid_XGB.best_estimator_ is already a trained model.

# If you need to re-train, you can do this:

# XGB_model_betterV = XGBClassifier(**grid_XGB.best_params_, use_label_encoder=False, eval_metric='logloss')
# XGB_model_betterV.fit(x_train, y_train)

# Now you can evaluate this final model on the test data
print("\n--- Final Model Evaluation ---")
test_accuracy = XGB_model_betterV.score(x_test, y_test)
print(f"Test Set Accuracy with Best Hyperparameters: {test_accuracy:.4f}")
# Out:
# --- Final Model Evaluation ---
# Test Set Accuracy with Best Hyperparameters: 0.9037

# %% [markdown]
# ## Confusion Matrix and Classification Reports

# %% [markdown]
# **Confusion Matrix**

# %% [markdown]
# - Plot confusion matrix to visualize result of model testing.

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Make predictions on the test dataset
y_predicted_XGB = XGB_model_betterV.predict(x_test)
# Create classification report
print("Classification Report:\n")
print(classification_report(y_test, y_predicted_XGB))

# Create confusion matrix
cm = confusion_matrix(y_test, y_predicted_XGB)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88       309
#          1.0       0.96      0.89      0.92       532
#
#     accuracy                           0.90       841
#    macro avg       0.89      0.91      0.90       841
# weighted avg       0.91      0.90      0.90       841

# %% [markdown]
# The classification report provides a detailed breakdown of precision, recall, and F1-score for each class. The model's performance for the "Approved" class is notably strong, with a precision of 96%, a recall of 89%, and an F1-score of 92%. However, the performance for the "Rejected" class is slightly lower, with a precision of 83%, a recall of 93%, and an F1-score of 88%. This suggests a slight bias toward predicting an approved loan. The overall accuracy of the model is 90.4%.

# %%
# Visualize Confusion Matrix using Seaborn
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues' , xticklabels=['Approved', 'Rejected'], yticklabels=['Approved', 'Rejected'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# The confusion matrix provides a clear breakdown of the model's predictions on the test dataset. Define meaning of TN, FN, FP, and TP for this dataset:
#
# - True Negatives (TN): Loans correctly predicted as rejected (484 applicants).
# - False Negatives (FN): Approved loans incorrectly predicted as rejected (17 applicants).
# - False Positives (FP): Rejected loans incorrectly predicted as approved (52 applicants).
# - True Positives (TP): Loans correctly predicted as approved (288 applicants).

# %% [markdown]
# ## Accuracy, Precision, Recall, and F1-Score

# %%
from sklearn.metrics import precision_recall_curve

# %%
# Assuming predicted probabilities from multiple models
preci_XGB, recall_XGB, _ = precision_recall_curve(y_test, y_predicted_XGB)

# Plot Precision-Recall Curves
plt.figure(figsize=(8, 6))
plt.plot(recall_XGB, preci_XGB, color='lightcoral', lw=2, label='XGB Classifier')
plt.plot([0, 1], [0.5, 0.5], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve Comparison of Models')
plt.legend(loc="lower left")
plt.show()

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
accuracy_XGB_model= sklearn.metrics.accuracy_score(y_test, y_predicted_XGB)
f1_XGB_model = f1_score(y_test, y_predicted_XGB, average='weighted')
precision_s = precision_score(y_test, y_predicted_XGB, average='weighted')
recall_s = recall_score(y_test, y_predicted_XGB, average='weighted')
print("Accuracy Score:", accuracy_XGB_model)
print('-'*100)
print("Precision:", precision_s)
print('-'*100)
print("Recall:", recall_s)
print('-'*100)
print("F1 Score:", f1_XGB_model)
print('-'*100)
# Out:
# Accuracy Score: 0.9036860879904876
# ----------------------------------------------------------------------------------------------------
# Precision: 0.9092328229613185
# ----------------------------------------------------------------------------------------------------
# Recall: 0.9036860879904876
# ----------------------------------------------------------------------------------------------------
# F1 Score: 0.9046714412278117
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### From result above, it can see that :
# - **Accuracy of the model is 90.37 percent, is a useful metric when errors in predicting all classes are equally important.**
# - Precision of the model is 90.92 percent.
# - Recall of the model is 90.36 percent.
# - **F1-Score of the model is 90.47 percent**, which is calculated by the mean of precision and recall.
#
# For this model, the accuracy value is very important because all classes are equally important. If the bank overapproves a loan for a person who does not meet the criteria, it means that they do not have the ability to return money to the bank, which can cause a default. If banks reject loans for customers who meet conditions, it means that bank will lose new customers and profit as well.

# %% [markdown]
# ## ROC Curve and Area under ROC Curve (AUC)

# %% [markdown]
# The ROC curve plots the model's True Positive Rate (TPR) against its False Positive Rate (FPR). A model that performs well will have a curve that bows towards the top-left corner of the plot, indicating a high TPR while maintaining a low FPR.
#
# - TPR close to 1 while keeping FPR near 0.
# - more area under the ROC Curve (AUC) indicated that obtain a good classifier.

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
# Assuming predicted probabilities for multiple models
yt_XGB, yp_XGB, _ = roc_curve(y_test, y_predicted_XGB)
roc_auc_XGB = auc(yt_XGB, yp_XGB)

# Plot ROC curves for multiple models
plt.figure(figsize=(8, 6))
plt.plot(yt_XGB, yp_XGB, color='lightcoral', lw=2, label='XGBoost Classifier' % roc_auc_XGB)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison of Models')
plt.legend(loc="lower right")
plt.show()

# %%
roc_auc_score_s = roc_auc_score(y_test, y_predicted_XGB, average='weighted')
print("Area under ROC Curve (AUC):", roc_auc_score_s)
# Out:
# Area under ROC Curve (AUC): 0.908950166678833

# %% [markdown]
# - The model's AUC is 0.91, which indicates a strong ability to distinguish between the two classes.

# %% [markdown]
# **Credit for Model Evaluation** : [see for Model Evaluation I](https://scikit-learn.org/stable/auto_examples/miscellaneous/plot_display_object_visualization.html#sphx-glr-auto-examples-miscellaneous-plot-display-object-visualization-py), [see for Model Evaluation II](https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#sphx-glr-auto-examples-model-selection-plot-precision-recall-py), [see for Model Evaluation III](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score), [see for Model Evaluation IV](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score)

# %% [markdown]
# # Discussion and Conclusion

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Conclusion**
#
# This project successfully developed a machine learning pipeline to assist a bank with its loan approval process. The pipeline followed a structured approach, starting with Exploratory Data Analysis (EDA), followed by Data Preprocessing to handle noisy data, Feature Engineering to transform variables, Model Training with nine different models, and finally, a detailed Model Assessment.
#
# The XGBoost model, with its optimal hyperparameters, was selected as the final model. It achieved a high level of performance with an overall accuracy of 90.4%, a precision of 90.9%, a recall of 90.4%, and an F1-score of 90.5%. The Area Under the ROC Curve (AUC) was 0.91, further confirming its strong predictive capability. While the model shows a slight bias toward predicting approved loans, its performance on the approved class is excellent, making it a valuable tool.

# %% [markdown]
# ## Discussion

# %% [markdown]
# **Disscussion**
#
# The performance of this model is highly promising for a real-world application in the banking sector. While a higher accuracy could be achieved, it might lead to overfitting, which would cause the model to perform poorly on new, unseen data. The current performance of around 90.4% strikes a good balance between predictive power and generalization. Given that banks process a high volume of loan applications daily, a model that can provide accurate predictions quickly would significantly reduce operational costs and the workload of the loan approval team.
#
# A key strength of this model is its ability to reduce the need for manual review, thereby saving costs and time. The most informative feature for predicting loan status is the cibil_score. The model's performance is further enhanced by a robust feature engineering pipeline, including dimensionality reduction and oversampling, which addresses potential issues like data imbalance.
#
# The primary limitation of the model is the slight bias it exhibits towards approving loans that should be rejected, as evidenced by the false positives in the confusion matrix. Although the overall error rate is around 9.6%, it is crucial to have human oversight to review the model's predictions and mitigate potential risks. Despite this, the model's strong performance and the efficiencies it introduces make it a valuable asset for the bank.
